# %%
# https://towardsdatascience.com/how-to-generate-dummy-data-in-python-a05bce24a6c6

# %%
# Install faker
# !pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-12.3.0-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\programdata\anaconda3\lib\site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Installing collected packages: Faker
# Successfully installed Faker-12.3.0

# %%
# Generating generic marketing data which will include some common columns (data format) like:
# Transaction date (timestamp)
# Customer name (string)
# Gender (boolean)
# Email (string)
# City (string)
# Purchased product ID — barcode (string)
# Amount spent (float)

# %%
import pandas as pd
import random
from faker import Faker
from random import randrange
from datetime import datetime

# %%
no_of_customers = 1000

# %%
fake = Faker()
customers = []

# %%
for customers_id in range(no_of_customers):
    # Create transaction date
    d1 = datetime.strptime(f'1/1/2021', '%d/%m/%Y')
    d2 = datetime.strptime(f'24/12/2021', '%d/%m/%Y')
    transaction_date = fake.date_between(d1,d2)
    
    # Create customer's name
    name = fake.name()
    
    # Create gender
    gender = random.choice(["M", "F"])
    
    # Create email
    email = fake.ascii_email()
    
    # Create city
    city = fake.city()
    
    # Create product ID in 8-digit barcode
    product_ID = fake.ean(length=8)
    
    # Create amount spent
    amount_spent = fake.pyfloat(right_digits=2, positive=True, min_value=1, max_value=100)
    
    customers.append([transaction_date, name, gender, email, city, product_ID, amount_spent])
    
print(customers)
# Out:
# [[datetime.date(2021, 4, 20), 'Jacob Hayes', 'M', 'bhammond@gmail.com', 'Henryside', '00253673', 13.62], [datetime.date(2021, 4, 3), 'Meagan Miller', 'F', 'katherinebennett@singh-knox.com', 'Hartbury', '82237707', 93.96], [datetime.date(2021, 5, 19), 'Robert Padilla', 'M', 'davisfrances@hotmail.com', 'Andersonland', '87659962', 3.1], [datetime.date(2021, 8, 14), 'Jennifer Farmer', 'M', 'norrisbrandon@jordan.net', 'Karenhaven', '24159142', 34.8], [datetime.date(2021, 8, 17), 'Jonathan Moore', 'M', 'perrylong@gmail.com', 'Youngmouth', '68029258', 7.8], [datetime.date(2021, 4, 8), 'Tanya Peters', 'F', 'michellejohnson@carter.com', 'New Catherineton', '58389355', 81.6], [datetime.date(2021, 11, 19), 'Justin Riley', 'F', 'henrythomas@sherman.biz', 'Paulchester', '05306848', 77.99], [datetime.date(2021, 6, 20), 'Dana Callahan', 'F', 'alan08@valdez.biz', 'West Ryan', '02189857', 74.16], [datetime.date(2021, 10, 3), 'Travis Duran', 'M', 'stephenerickson@cooper.com', 'Bryanthaven', '70008166', 6.38], [datetime.date(2021, 11, 26), 'Richard Edwards', 'F', 'joshuapeck@sims.info', 'Lake Davidmouth', '47359871', 12.25], [datetime.date(2021, 8, 22), 'James Bennett', 'M', 'tphillips@yahoo.com', 'East Tomland', '57772097', 52.74], [datetime.date(2021, 7, 24), 'David Parks', 'F', 'dawn45@diaz.net', 'Port Tanya', '82335007', 36.4], [datetime.date(2021, 12, 19), 'Jonathan Garcia', 'F', 'martinlopez@ortiz.com', 'West Thomas', '11783633', 95.65], [datetime.date(2021, 6, 21), 'Caitlin Porter', 'M', 'rebeccalarson@thornton.com', 'East Kristen', '68169756', 43.37], [datetime.date(2021, 10, 15), 'Tammy Mills', 'M', 'robertjohnson@gmail.com', 'Christopherland', '42414483', 33.13], [datetime.date(2021, 7, 8), 'Catherine Mays', 'M', 'dsmith@pitts.com', 'West Kaylafort', '24890212', 40.7], [datetime.date(2021, 8, 26), 'Molly Ali', 'M', 'danielbullock@wang.com', 'Jefferymouth', '51296698', 95.78], [datetime.date(2021, 11, 14), 'Lori Kelly', 'F', 'garrettamy@rich-green.com', 'Carriefort', '91986467', 89.6], [datetime.date(2021, 12, 9), 'Megan Peters', 'F', 'danielle19@moore.com', 'Lisaburgh', '71088594', 8.31], [datetime.date(2021, 2, 22), 'Donald Molina', 'M', 'harrismelissa@coleman.org', 'Newmanborough', '47149038', 5.76], [datetime.date(2021, 9, 2), 'Randy Dennis', 'F', 'amanda73@lewis.com', 'East Thomas', '68033859', 16.46], [datetime.date(2021, 7, 30), 'Philip Fry', 'F', 'elizabeth04@wells.com', 'North Jessica', '81211548', 79.45], [datetime.date(2021, 4, 24), 'Allison Castillo', 'F', 'brandon95@gmail.com', 'Lake Shawn', '68025212', 63.35], [datetime.date(2021, 2, 16), 'Grace Blackburn MD', 'M', 'brettwalker@acevedo.com', 'North Timothy', '42500063', 35.63], [datetime.date(2021, 7, 15), 'Charles Rocha', 'M', 'aliciamatthews@johnson-adams.com', 'West Barbaraton', '01920765', 42.23], [datetime.date(2021, 8, 14), 'Greg Ortega', 'F', 'cindybutler@yahoo.com', 'Rothchester', '44660963', 36.33], [datetime.date(2021, 4, 23), 'Joshua Fisher', 'M', 'bobby88@morgan.net', 'Davidsonborough', '97819080', 67.8], [datetime.date(2021, 4, 21), 'Jessica Salas', 'F', 'christopherbrown@gmail.com', 'New Shannon', '80980063', 78.15], [datetime.date(2021, 8, 4), 'Stanley Mcdonald', 'F', 'jennifer99@yahoo.com', 'Johnsonville', '11038795', 21.26], [datetime.date(2021, 2, 9), 'Danny Sandoval', 'M', 'riveradanielle@yahoo.com', 'Christinechester', '63735116', 32.14], [datetime.date(2021, 12, 16), 'Julie Keller', 'M', 'wilsonemily@wilson.com', 'North Kristen', '37962524', 8.41], [datetime.date(2021, 8, 22), 'April Alexander', 'F', 'ruizjoe@gmail.com', 'Port Jessica', '86364041', 1.87], [datetime.date(2021, 4, 6), 'Cameron Bryant', 'F', 'emilycalderon@gmail.com', 'Gonzalezchester', '86541312', 98.92], [datetime.date(2021, 2, 26), 'John Dennis', 'M', 'ashleygarcia@yahoo.com', 'Sweeneyview', '78863330', 50.23], [datetime.date(2021, 7, 26), 'Andrew Schultz', 'M', 'catherinevargas@vance-norton.com', 'Ericksonhaven', '52650666', 55.51], [datetime.date(2021, 11, 21), 'Kristen Rodriguez', ' ...

# %%
customers_df = pd.DataFrame(customers, columns=['Transaction_data', 'Name', 'Gender', 'Email', 'City', 'Product ID', 'Amount'])

pd.pandas.set_option('display.max_columns', None)
print(customers_df)
# Out:
#     Transaction_data              Name Gender  \
# 0         2021-04-20       Jacob Hayes      M
# 1         2021-04-03     Meagan Miller      F
# 2         2021-05-19    Robert Padilla      M
# 3         2021-08-14   Jennifer Farmer      M
# 4         2021-08-17    Jonathan Moore      M
# ..               ...               ...    ...
# 995       2021-11-09        Susan Rowe      F
# 996       2021-02-21  Whitney Hatfield      F
# 997       2021-07-30     David Elliott      M
# 998       2021-10-14       Lisa Murphy      M
# 999       2021-09-03       Tracy Smith      F
#
#                                  Email               City Product ID  Amount
# 0                   bhammond@gmail.com          Henryside   00253673   13.62
# 1      katherinebennett@singh-knox.com           Hartbury   82237707   93.96
# 2             davisfrances@hotmail.com       Andersonland   87659962    3.10
# 3             norrisbrandon@jordan.net         Karenhaven   24159142   34.80
# 4                  perrylong@gmail.com         Youngmouth   68029258    7.80
# ..                                 ...                ...        ...     ...
# 995           cmitchell@strickland.net            Foxberg   96780848   11.30
# 996  jessicasullivan@chen-thompson.com           Jacktown   28678311   52.40
# 997          thomasjackson@hotmail.com  Port Christinaton   93353137   19.44
# 998                   lisa85@gmail.com  South Nicolemouth   22775177   18.12
# 999                amanda54@thomas.biz         Hansonberg   31129060   63.20
#
# [1000 rows x 7 columns]

# %%
# Insert dummy data to MongoDB
import pymongo
#"mongodb+srv://USERNAME:PASSWORD@cluster0.2wjy8.mongodb.net/DATABASENAME
client = pymongo.MongoClient("mongodb+srv://mongodb:mongodb@cluster0.2wjy8.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.2wjy8.mongodb.net:27017', 'cluster0-shard-00-02.2wjy8.mongodb.net:27017', 'cluster0-shard-00-00.2wjy8.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-f9ce2x-shard-0', tls=True), 'test')

# %%
print(client.list_database_names())
# Out:
# ['sudh', 'admin', 'local']

# %%
# MySQL                MongoDB
# DB                   DB
# Table                Collection
# Row/Record           Document

# %%
db2 = client['CustomerTransaction'] # DB

# %%
coll1 = db2['Tx_Data_Collection'] # Collection/Table Name

# %%
# Transaction date (timestamp)
# Customer name (string)
# Gender (boolean)
# Email (string)
# City (string)
# Purchased product ID — barcode (string)
# Amount spent (float)
# print(customers)
customers_updated = []
keys = ['transaction_date', 'name', 'gender', 'email', 'city', 'product_barcode', 'amount_spent']
for listItem in customers:
    listToStr = ','.join(map(str, listItem)) # join and split to put date and numbers into quotes
    res = dict(zip(keys, listToStr.split(',')))
    customers_updated.append(res)

customers_updated
# Out:
# [{'transaction_date': '2021-04-20',
#   'name': 'Jacob Hayes',
#   'gender': 'M',
#   'email': 'bhammond@gmail.com',
#   'city': 'Henryside',
#   'product_barcode': '00253673',
#   'amount_spent': '13.62'},
#  {'transaction_date': '2021-04-03',
#   'name': 'Meagan Miller',
#   'gender': 'F',
#   'email': 'katherinebennett@singh-knox.com',
#   'city': 'Hartbury',
#   'product_barcode': '82237707',
#   'amount_spent': '93.96'},
#  {'transaction_date': '2021-05-19',
#   'name': 'Robert Padilla',
#   'gender': 'M',
#   'email': 'davisfrances@hotmail.com',
#   'city': 'Andersonland',
#   'product_barcode': '87659962',
#   'amount_spent': '3.1'},
#  {'transaction_date': '2021-08-14',
#   'name': 'Jennifer Farmer',
#   'gender': 'M',
#   'email': 'norrisbrandon@jordan.net',
#   'city': 'Karenhaven',
#   'product_barcode': '24159142',
#   'amount_spent': '34.8'},
#  {'transaction_date': '2021-08-17',
#   'name': 'Jonathan Moore',
#   'gender': 'M',
#   'email': 'perrylong@gmail.com',
#   'city': 'Youngmouth',
#   'product_barcode': '68029258',
#   'amount_spent': '7.8'},
#  {'transaction_date': '2021-04-08',
#   'name': 'Tanya Peters',
#   'gender': 'F',
#   'email': 'michellejohnson@carter.com',
#   'city': 'New Catherineton',
#   'product_barcode': '58389355',
#   'amount_spent': '81.6'},
#  {'transaction_date': '2021-11-19',
#   'name': 'Justin Riley',
#   'gender': 'F',
#   'email': 'henrythomas@sherman.biz',
#   'city': 'Paulchester',
#   'product_barcode': '05306848',
#   'amount_spent': '77.99'},
#  {'transaction_date': '2021-06-20',
#   'name': 'Dana Callahan',
#   'gender': 'F',
#   'email': 'alan08@valdez.biz',
#   'city': 'West Ryan',
#   'product_barcode': '02189857',
#   'amount_spent': '74.16'},
#  {'transaction_date': '2021-10-03',
#   'name': 'Travis Duran',
#   'gender': 'M',
#   'email': 'stephenerickson@cooper.com',
#   'city': 'Bryanthaven',
#   'product_barcode': '70008166',
#   'amount_spent': '6.38'},
#  {'transaction_date': '2021-11-26',
#   'name': 'Richard Edwards',
#   'gender': 'F',
#   'email': 'joshuapeck@sims.info',
#   'city': 'Lake Davidmouth',
#   'product_barcode': '47359871',
#   'amount_spent': '12.25'},
#  {'transaction_date': '2021-08-22',
#   'name': 'James Bennett',
#   'gender': 'M',
#   'email': 'tphillips@yahoo.com',
#   'city': 'East Tomland',
#   'product_barcode': '57772097',
#   'amount_spent': '52.74'},
#  {'transaction_date': '2021-07-24',
#   'name': 'David Parks',
#   'gender': 'F',
#   'email': 'dawn45@diaz.net',
#   'city': 'Port Tanya',
#   'product_barcode': '82335007',
#   'amount_spent': '36.4'},
#  {'transaction_date': '2021-12-19',
#   'name': 'Jonathan Garcia',
#   'gender': 'F',
#   'email': 'martinlopez@ortiz.com',
#   'city': 'West Thomas',
#   'product_barcode': '11783633',
#   'amount_spent': '95.65'},
#  {'transaction_date': '2021-06-21',
#   'name': 'Caitlin Porter',
#   'gender': 'M',
#   'email': 'rebeccalarson@thornton.com',
#   'city': 'East Kristen',
#   'product_barcode': '68169756',
#   'amount_spent': '43.37'},
#  {'transaction_date': '2021-10-15',
#   'name': 'Tammy Mills',
#   'gender': 'M',
#   'email': 'robertjohnson@gmail.com',
#   'city': 'Christopherland',
#   'product_barcode': '42414483',
#   'amount_spent': '33.13'},
#  {'transaction_date': '2021-07-08',
#   'name': 'Catherine Mays',
#   'gender': 'M',
#   'email': 'dsmith@pitts.com',
#   'city': 'West Kaylafort',
#   'product_barcode': '24890212',
#   'amount_spent': '40.7'},
#  {'transaction_date': '2021-08-26',
#   'name': 'Molly Ali',
#   'gender': 'M',
#   'email': 'danielbullock@wang.com',
#   'city': 'Jefferymouth',
#   'product_barcode': '51296698',
#   'amount_spent': '95.78'},
#  {'transaction_date': '2021-11-14',
#   'name': 'Lori Kelly',
#   'gender': 'F',
#   'email': 'garrettamy@rich-green.com',
#   'city': 'Carriefort',
#   'product_barcode': '91986467',
#   'amount_spent': '89.6'},
#  {'transaction_date': '2021-12-09',
#   'name': 'Megan Peters',
#   'gender': 'F',
#   'email': 'danielle19@moore.com',
#   'city': 'Lisaburgh',
#   'product_barcode': '71088594',
#   'amount_spent': '8.31'},
#  {'transaction_date': '2021-02-22',
#   'name': 'Donald Molina',
#   'gender': 'M',
#   'email': 'harrismelissa@coleman.org',
#   'city': 'Newmanborough',
#   'product_barcode': '47149038',
#   'amount_spent': '5.76'},
#  {'transaction_date': '2021-09-02',
#   'name': 'Randy Dennis',
#   'gender': 'F',
#   'email': 'amanda73@lewis.com',
#   'city': 'East Thomas',
#   'product_barcode': '68033859',
#   'amount_spent': '16.46'},
#  {'transaction_date': '2021-07-30',
#   'name': 'Philip Fry',
#   'gender': 'F',
#   'email': 'elizabeth04@wells.com',
#   'city': 'North Jessica',
#   'product_barcode': '81211548',
#   'amount_spent': '79.45'},
#  {'transaction_date': '2021-04-24',
#   'name': 'Allison Castillo',
#   'gender': 'F',
#   'email': 'brandon95@gmail.com',
#   'city': 'Lake Shawn',
#   'product_barcode': '68025212',
#   'amount_spent': '63.35'},
#  {'transaction_date': '2021-02-16',
#   'name': 'Grace Blackburn MD',
#   'gender': 'M',
#   'email': 'brettwalker@acevedo.com',
#   'city': 'North Timothy',
#   'product_barcode': '42500063',
#   'amount_spent': '35.63'},
#  {'transaction_date': '2021-07-15',
#   'name': 'Charles Rocha',
#   'gender': 'M',
#   'email': 'aliciamatthews@johnson-adams.com',
#   'city': 'West Barbaraton',
#   'product_barcode': '01920765',
#   'amount_spent': '42.23'},
#  {'transaction_date': '2021-08-14',
#   'name': 'Greg Ortega',
#   'gender': 'F',
#   'email': 'cindybutler@yahoo.com',
#   'city': 'Rothchester',
#   'product_barcode': '44660963',
#   'amount_spent': '36.33'},
#  {'transaction_date': '2021-04-23',
#   'name': 'Joshua Fisher',
#   'gender': 'M',
#   'email': 'bobby88@morgan.net',
#   'city': 'Davidsonborough',
#   'product_barcode': '97819080',
#   'amount_spent': '67.8'},
#  {'transaction_date': '2021-04-21',
#   'name': 'Jessica Salas',
#   'gender': 'F',
#   'email': 'christopherbrown@gmail.com',
#   'city': 'New Shannon',
#   'product_barcode': '80980063',
#   'amount_spent': '78.15'},
#  {'transaction_date': '2021-08-04',
#   'name': 'Stanley Mcdonald',
#   'gender': 'F',
#   'email': 'jennifer99@yahoo.com',
#   'city': 'Johnsonville',
#   'product_barcode': '11038795',
#   'amount_spent': '21.26'},
#  {'transaction_date': '2021-02-09',
#   'name': 'Danny Sandoval',
#   'gender': 'M',
#   'email': 'riveradanielle@yahoo.com',
#   'city': 'Christinechester',
#   'product_barcode': '63735116',
#   'amount_spent': '32.14'},
#  {'transaction_date': '2021-12-16',
#   'name': 'Julie Keller',
#   'gender': 'M',
#   'email': 'wilsonemily@wilson.com',
#   'city': 'North Kristen',
#   'product_barcode': '37962524',
#   'amount_spent': '8.41'},
#  {'transaction_date': '2021-08-22',
#   'name': 'April Alexander',
#   'gender': 'F',
#   'email': 'ruizjoe@gmail.com',
#   'city': 'Port Jessica',
#   'product_barcode': '86364041',
#   'amount_spent': '1.87'},
#  {'transaction_date': '2021-04-06',
#   'name': 'Cameron Bryant',
#   'gender': 'F',
#   'email': 'emilycalderon@gmail.com',
#   'city': 'Gonzalezchester',
#   'product_barcode': '86541312',
#   'amount_spent': '98.92'},
#  {'transaction_date': '2021-02-26',
#   'name': 'John Dennis',
#   'gender': 'M',
#   'email': 'ashleygarcia@yahoo.com',
#   'city': 'Sweeneyview',
#   'product_barcode': '78863330',
#   'amount_spent': '50.23'},
#  {'transaction_date': '2021-07-26',
#   'name': 'Andrew Schultz',
#   'gender': 'M',
#   'email': 'catherinevargas@vance-norton.com',
#   'city': 'Ericksonhaven',
#   'product_barcode': '52650666',
#   'amount_spent': '55.51'},
#  {'transaction_date': '2021-11-21',
#   'name': 'Kristen Rodriguez',
#   'gender': 'M',
#   'email': 'aarondominguez@pham.org',
#   'city': 'West Kellyshire',
#   'product_barcode': '67510979',
#   'amount_spent': '89.67'},
#  {'transaction_date': '2021-01-07',
#   'name': 'Tina Hansen',
#   'gender': 'M',
#   'email': 'richard27@may.com',
#   'city': 'Port Megan',
#   'product_barcode': '15792778',
#   'amount_spent': '22.38'},
#  {'transaction_date': '2021-02-02',
#   'name': 'Michael Garcia',
#   'gender': 'M',
#   'email': 'lindaniel@gmail.com',
#   'city': 'Danielsstad',
#   'product_barcode': '92690776',
#   'amount_spent': '75.44'},
#  {'transaction_date': '2021-10-13',
#   'name': 'Chad Miller',
#   'gender': 'F',
#   'email': 'kevin45@jackson.biz',
#   'city': 'Lindseyborough',
#   'product_barcode': '90756993',
#   'amount_spent': '63.9'},
#  {'transaction_date': '2021-10-04',
#   'name': 'Brandon Brown',
#   'gender': 'M',
#   'email': 'patrickstone@schneider-ramirez.com',
#   'city': 'Port Saraton',
#   'product_barcode': '89960509',
#   'amount_spent': '59.64'},
#  {'transaction_date': '2021-10-03',
#   'name': 'Ryan King',
#   'gender': 'M',
#   'email': 'carmenchambers@hotmail.com',
#   'city': 'South Steven',
#   'product_barcode': '35257448',
#   'amount_spent': '17.75'},
#  {'transaction_date': '2021-07-31',
#   'name': 'Adriana Robinson',
#   'gender': 'F',
#   'email': 'jeffrey81@yahoo.com',
#   'city': 'East Andrewborough',
#   'product_barcode': '28287803',
#   'amount_spent': '29.81'},
#  {'transaction_date': '2021-10-13',
#   'name': 'Michelle Davis',
#   'gender': 'F',
#   'email': 'hudsonashley@hotmail.com',
#   'city': 'Carolinemouth',
#   'product_barcode': '01687781',
#   'amount_spent': '89.31'},
#  {'transaction_date': '2021-04-14',
#   'name': 'Krystal Hess',
#   'gender': 'F',
#   'email': 'tbrown@hunter.com',
#   'city': 'Lake Richardburgh',
#   'product_barcode': '22520999',
#   'amount_spent': '21.61'},
#  {'transaction_date': '2021-05-24',
#   'name': 'Dakota Williamson',
#   'gender': 'F',
#   'email': 'madisongonzales@hotmail.com',
#   'city': 'South Carlberg',
#   'product_barcode': '86357951',
#   'amount_spent': '3.56'},
#  {'transaction_date': '2021-05-02',
#   'name': 'Michael Ward',
#   'gender': 'F',
#   'email': 'vgarrison@thompson-reed.com',
#   'city': 'Holtside',
#   'product_barcode': '54898912',
#   'amount_spent': '15.13'},
#  {'transaction_date': '2021-06-29',
#   'name': 'Danielle Prince',
#   'gender': 'F',
#   'email': 'michaelvincent@martin.net',
#   'city': 'Gregoryton',
#   'product_barcode': '73325031',
#   'amount_spent': '32.9'},
#  {'transaction_date': '2021-02-01',
#   'name': 'Jacqueline Shaffer',
#   'gender': 'M',
#   'email': 'hallwilliam@gmail.com',
#   'city': 'Caitlinhaven',
#   'product_barcode': '94343496',
#   'amount_spent': '60.92'},
#  {'transaction_date': '2021-10-07',
#   'name': 'Patricia Nelson',
#   'gender': 'F',
#   'email': 'johnsonmolly@yahoo.com',
#   'city': 'Lake Danaton',
#   'product_barcode': '32282535',
#   'amount_spent': '74.66'},
#  {'transaction_date': '2021-04-30',
#   'name': 'Jon Norton',
#   'gender': 'M',
#   'email': 'underwoodamy@randolph.org',
#   'city': 'Fraziermouth',
#   'product_barcode': '28392477',
#   'amount_spent': '31.71'},
#  {'transaction_date': '2021-04-04',
#   'name': 'Brian Martinez',
#   'gender': 'F',
#   'email': 'brownelizabeth@gaines.com',
#   'city': 'Carsonborough',
#   'product_barcode': '91717597',
#   'amount_spent': '47.87'},
#  {'transaction_date': '2021-01-23',
#   'name': 'Michael Gonzalez',
#   'gender': 'M',
#   'email': 'joycebrown@hurst-hernandez.net',
#   'city': 'Goodberg',
#   'product_barcode': '03560211',
#   'amount_spent': '35.41'},
#  {'transaction_date': '2021-01-05',
#   'name': 'Ronald Mitchell',
#   'gender': 'F',
#   'email': 'sdavis@gmail.com',
#   'city': 'Wandaberg',
#   'product_barcode': '74037766',
#   'amount_spent': '16.3'},
#  {'transaction_date': '2021-08-15',
#   'name': 'James Avila',
#   'gender': 'F',
#   'email': 'sarah91@yahoo.com',
#   'city': 'East Kylie',
#   'product_barcode': '78926882',
#   'amount_spent': '53.6'},
#  {'transaction_date': '2021-05-21',
#   'name': 'Felicia Zimmerman',
#   'gender': 'M',
#   'email': 'fullerchristina@vaughn.net',
#   'city': 'East Christineport',
#   'product_barcode': '70848649',
#   'amount_spent': '75.5'},
#  {'transaction_date': '2021-03-17',
#   'name': 'John Harding',
#   'gender': 'F',
#   'email': 'mdavis@gmail.com',
#   'city': 'Lake Christinabury',
#   'product_barcode': '19823041',
#   'amount_spent': '54.34'},
#  {'transaction_date': '2021-10-31',
#   'name': 'Michael Turner',
#   'gender': 'M',
#   'email': 'cruzmonique@hotmail.com',
#   'city': 'West Joshua',
#   'product_barcode': '50296224',
#   'amount_spent': '83.1'},
#  {'transaction_date': '2021-06-29',
#   'name': 'Ashley Ross',
#   'gender': 'F',
#   'email': 'gloria36@hotmail.com',
#   'city': 'Port Rhondaburgh',
#   'product_barcode': '75433901',
#   'amount_spent': '55.41'},
#  {'transaction_date': '2021-01-01',
#   'name': 'Elizabeth Bowen',
#   'gender': 'M',
#   'email': 'jbrady@gmail.com',
#   'city': 'Elizabethhaven',
#   'product_barcode': '12931170',
#   'amount_spent': '34.55'},
#  {'transaction_date': '2021-07-09',
#   'name': 'Jennifer Washington',
#   'gender': 'F',
#   'email': 'ipotts@hotmail.com',
#   'city': 'West Tammyville',
#   'product_barcode': '82620714',
#   'amount_spent': '85.67'},
#  {'transaction_date': '2021-06-25',
#   'name': 'Lisa Mercado',
#   'gender': 'M',
#   'email': 'fernando57@gmail.com',
#   'city': 'Smithport',
#   'product_barcode': '07611292',
#   'amount_spent': '93.29'},
#  {'transaction_date': '2021-01-27',
#   'name': 'Jasmine Wilson',
#   'gender': 'M',
#   'email': 'josephrogers@gmail.com',
#   'city': 'South Matthew',
#   'product_barcode': '35070818',
#   'amount_spent': '37.49'},
#  {'transaction_date': '2021-06-16',
#   'name': 'Larry Garcia',
#   'gender': 'F',
#   'email': 'briandaugherty@wise.com',
#   'city': 'West Brianna',
#   'product_barcode': '56497571',
#   'amount_spent': '88.77'},
#  {'transaction_date': '2021-07-01',
#   'name': 'Abigail Wilson',
#   'gender': 'F',
#   'email': 'raystephanie@nelson.com',
#   'city': 'Nelsontown',
#   'product_barcode': '35521563',
#   'amount_spent': '20.93'},
#  {'transaction_date': '2021-04-26',
#   'name': 'Andrew Morgan',
#   'gender': 'M',
#   'email': 'glenn76@stevens.com',
#   'city': 'Santostown',
#   'product_barcode': '94191370',
#   'amount_spent': '1.85'},
#  {'transaction_date': '2021-09-20',
#   'name': 'Vanessa Edwards',
#   'gender': 'F',
#   'email': 'emily69@lam.com',
#   'city': 'Lake Billberg',
#   'product_barcode': '07017902',
#   'amount_spent': '68.38'},
#  {'transaction_date': '2021-10-05',
#   'name': 'Jennifer Schmidt',
#   'gender': 'F',
#   'email': 'lindseyjohnson@romero.com',
#   'city': 'Barnetttown',
#   'product_barcode': '17947237',
#   'amount_spent': '2.6'},
#  {'transaction_date': '2021-03-30',
#   'name': 'Michelle Green',
#   'gender': 'M',
#   'email': 'darlenemcmahon@bautista.com',
#   'city': 'Shellyburgh',
#   'product_barcode': '44018023',
#   'amount_spent': '9.29'},
#  {'transaction_date': '2021-03-09',
#   'name': 'Elijah Perez',
#   'gender': 'F',
#   'email': 'myang@hotmail.com',
#   'city': 'Frenchberg',
#   'product_barcode': '54502000',
#   'amount_spent': '13.49'},
#  {'transaction_date': '2021-11-28',
#   'name': 'Randy Anderson',
#   'gender': 'M',
#   'email': 'melendezmichele@ellis-larson.com',
#   'city': 'Georgeside',
#   'product_barcode': '17916394',
#   'amount_spent': '48.33'},
#  {'transaction_date': '2021-05-05',
#   'name': 'Robert Marks',
#   'gender': 'F',
#   'email': 'david99@gmail.com',
#   'city': 'Johnfort',
#   'product_barcode': '86447973',
#   'amount_spent': '84.53'},
#  {'transaction_date': '2021-03-15',
#   'name': 'Ricardo Strickland',
#   'gender': 'F',
#   'email': 'chris76@hotmail.com',
#   'city': 'South Caroline',
#   'product_barcode': '30139916',
#   'amount_spent': '58.25'},
#  {'transaction_date': '2021-11-24',
#   'name': 'James Johnson',
#   'gender': 'M',
#   'email': 'carolanderson@hall.com',
#   'city': 'West Tiffanyfurt',
#   'product_barcode': '48677585',
#   'amount_spent': '63.3'},
#  {'transaction_date': '2021-04-19',
#   'name': 'Steven Stafford',
#   'gender': 'M',
#   'email': 'spalmer@hubbard-brown.info',
#   'city': 'Loriside',
#   'product_barcode': '16845206',
#   'amount_spent': '26.9'},
#  {'transaction_date': '2021-10-19',
#   'name': 'Jennifer Carter',
#   'gender': 'M',
#   'email': 'mcdanielholly@gmail.com',
#   'city': 'New Jerryfort',
#   'product_barcode': '18424515',
#   'amount_spent': '45.97'},
#  {'transaction_date': '2021-02-14',
#   'name': 'Heather Haynes',
#   'gender': 'M',
#   'email': 'jonathan55@hotmail.com',
#   'city': 'Lake Williamborough',
#   'product_barcode': '51989088',
#   'amount_spent': '77.37'},
#  {'transaction_date': '2021-04-26',
#   'name': 'Ryan Schultz',
#   'gender': 'M',
#   'email': 'brian74@martin.net',
#   'city': 'North Josephbury',
#   'product_barcode': '19624860',
#   'amount_spent': '13.47'},
#  {'transaction_date': '2021-09-25',
#   'name': 'Adam Ho',
#   'gender': 'M',
#   'email': 'masonashley@yahoo.com',
#   'city': 'Christophermouth',
#   'product_barcode': '41922033',
#   'amount_spent': '67.4'},
#  {'transaction_date': '2021-01-07',
#   'name': 'Dalton Garza',
#   'gender': 'F',
#   'email': 'patrick80@lopez-crawford.com',
#   'city': 'North Amanda',
#   'product_barcode': '02587493',
#   'amount_spent': '96.22'},
#  {'transaction_date': '2021-02-14',
#   'name': 'Sheila Good',
#   'gender': 'M',
#   'email': 'maryschmidt@young.com',
#   'city': 'South Lesliestad',
#   'product_barcode': '52243783',
#   'amount_spent': '9.36'},
#  {'transaction_date': '2021-10-06',
#   'name': 'Tara Williams',
#   'gender': 'M',
#   'email': 'eugenedougherty@kramer.com',
#   'city': 'Keithport',
#   'product_barcode': '50533275',
#   'amount_spent': '71.83'},
#  {'transaction_date': '2021-10-22',
#   'name': 'Keith Torres',
#   'gender': 'M',
#   'email': 'croberts@gmail.com',
#   'city': 'Lake Emily',
#   'product_barcode': '00557276',
#   'amount_spent': '19.69'},
#  {'transaction_date': '2021-02-15',
#   'name': 'John Williams',
#   'gender': 'M',
#   'email': 'chavezrobert@roach.com',
#   'city': 'Port Andrewmouth',
#   'product_barcode': '10411933',
#   'amount_spent': '18.9'},
#  {'transaction_date': '2021-02-10',
#   'name': 'Nancy Berry',
#   'gender': 'M',
#   'email': 'joshuanoble@anderson.net',
#   'city': 'New John',
#   'product_barcode': '11819554',
#   'amount_spent': '35.65'},
#  {'transaction_date': '2021-02-21',
#   'name': 'Daniel Adkins',
#   'gender': 'M',
#   'email': 'danielmartin@moore.info',
#   'city': 'New Nicholasborough',
#   'product_barcode': '85191068',
#   'amount_spent': '74.1'},
#  {'transaction_date': '2021-12-16',
#   'name': 'Bradley Diaz',
#   'gender': 'M',
#   'email': 'hrichards@yahoo.com',
#   'city': 'Johnsontown',
#   'product_barcode': '94503814',
#   'amount_spent': '28.84'},
#  {'transaction_date': '2021-01-04',
#   'name': 'David Davis',
#   'gender': 'M',
#   'email': 'rachel75@weiss.com',
#   'city': 'South Donfort',
#   'product_barcode': '71727745',
#   'amount_spent': '30.28'},
#  {'transaction_date': '2021-03-09',
#   'name': 'Kaylee Aguirre',
#   'gender': 'M',
#   'email': 'leblancandrew@gmail.com',
#   'city': 'East Janebury',
#   'product_barcode': '33105352',
#   'amount_spent': '99.67'},
#  {'transaction_date': '2021-08-06',
#   'name': 'Nathan Allen',
#   'gender': 'M',
#   'email': 'qgonzalez@hotmail.com',
#   'city': 'New Joshuaberg',
#   'product_barcode': '79551168',
#   'amount_spent': '52.31'},
#  {'transaction_date': '2021-07-04',
#   'name': 'Johnny Castro',
#   'gender': 'M',
#   'email': 'jamie12@kennedy.com',
#   'city': 'Gutierrezbury',
#   'product_barcode': '77291172',
#   'amount_spent': '46.42'},
#  {'transaction_date': '2021-11-16',
#   'name': 'Jessica Wilson',
#   'gender': 'F',
#   'email': 'qgriffin@golden.com',
#   'city': 'North Angela',
#   'product_barcode': '48045889',
#   'amount_spent': '52.82'},
#  {'transaction_date': '2021-05-27',
#   'name': 'John Watson',
#   'gender': 'F',
#   'email': 'david06@hotmail.com',
#   'city': 'Karenfurt',
#   'product_barcode': '55604802',
#   'amount_spent': '83.44'},
#  {'transaction_date': '2021-04-24',
#   'name': 'John Miller',
#   'gender': 'F',
#   'email': 'christophergreene@fitzgerald.com',
#   'city': 'Maryville',
#   'product_barcode': '46633019',
#   'amount_spent': '46.47'},
#  {'transaction_date': '2021-08-19',
#   'name': 'Nicholas Logan',
#   'gender': 'F',
#   'email': 'wmullins@ward.biz',
#   'city': 'Brianstad',
#   'product_barcode': '30242227',
#   'amount_spent': '9.83'},
#  {'transaction_date': '2021-06-20',
#   'name': 'Jack White',
#   'gender': 'F',
#   'email': 'fbaker@yahoo.com',
#   'city': 'Palmerport',
#   'product_barcode': '93973205',
#   'amount_spent': '72.87'},
#  {'transaction_date': '2021-11-19',
#   'name': 'Cory Cook',
#   'gender': 'F',
#   'email': 'christopher41@armstrong.com',
#   'city': 'East Karenfort',
#   'product_barcode': '80214953',
#   'amount_spent': '56.51'},
#  {'transaction_date': '2021-10-01',
#   'name': 'Amy Finley',
#   'gender': 'M',
#   'email': 'stephanie89@gmail.com',
#   'city': 'Angelastad',
#   'product_barcode': '32766950',
#   'amount_spent': '85.37'},
#  {'transaction_date': '2021-04-30',
#   'name': 'Erin Wood',
#   'gender': 'F',
#   'email': 'wchristensen@peterson.com',
#   'city': 'Rodriguezfurt',
#   'product_barcode': '95775951',
#   'amount_spent': '11.46'},
#  {'transaction_date': '2021-09-15',
#   'name': 'Sherry Smith',
#   'gender': 'M',
#   'email': 'courtneygrimes@king-wilson.com',
#   'city': 'Juliafurt',
#   'product_barcode': '78689183',
#   'amount_spent': '80.12'},
#  {'transaction_date': '2021-02-28',
#   'name': 'Morgan Harris',
#   'gender': 'F',
#   'email': 'howelldebra@hotmail.com',
#   'city': 'Pamelaview',
#   'product_barcode': '16563315',
#   'amount_spent': '26.42'},
#  {'transaction_date': '2021-07-09',
#   'name': 'Cindy Bradley',
#   'gender': 'M',
#   'email': 'penasteven@evans-brown.com',
#   'city': 'West Stephanie',
#   'product_barcode': '46772398',
#   'amount_spent': '10.65'},
#  {'transaction_date': '2021-06-13',
#   'name': 'Kimberly Sullivan',
#   'gender': 'F',
#   'email': 'gwilcox@gmail.com',
#   'city': 'Yvonneside',
#   'product_barcode': '05749003',
#   'amount_spent': '21.12'},
#  {'transaction_date': '2021-11-03',
#   'name': 'Brett Gonzalez',
#   'gender': 'M',
#   'email': 'knightchristopher@yahoo.com',
#   'city': 'Woodsfurt',
#   'product_barcode': '29263301',
#   'amount_spent': '69.13'},
#  {'transaction_date': '2021-08-29',
#   'name': 'Melissa Wilson',
#   'gender': 'M',
#   'email': 'matthewjohnson@hotmail.com',
#   'city': 'New Stephaniehaven',
#   'product_barcode': '85113831',
#   'amount_spent': '3.31'},
#  {'transaction_date': '2021-07-11',
#   'name': 'Megan Moreno',
#   'gender': 'F',
#   'email': 'edwardspeggy@yahoo.com',
#   'city': 'Chambersview',
#   'product_barcode': '54868977',
#   'amount_spent': '12.41'},
#  {'transaction_date': '2021-10-28',
#   'name': 'Adam Phillips',
#   'gender': 'M',
#   'email': 'timothy54@yahoo.com',
#   'city': 'Morganburgh',
#   'product_barcode': '15333445',
#   'amount_spent': '36.12'},
#  {'transaction_date': '2021-11-21',
#   'name': 'David Wiggins',
#   'gender': 'M',
#   'email': 'suzanne32@smith.org',
#   'city': 'Knoxchester',
#   'product_barcode': '10487860',
#   'amount_spent': '83.5'},
#  {'transaction_date': '2021-03-30',
#   'name': 'Carolyn Ayers',
#   'gender': 'M',
#   'email': 'gwebb@hotmail.com',
#   'city': 'Collinsmouth',
#   'product_barcode': '06577230',
#   'amount_spent': '42.76'},
#  {'transaction_date': '2021-08-21',
#   'name': 'John Mitchell',
#   'gender': 'F',
#   'email': 'anita60@johnson.com',
#   'city': 'New Becky',
#   'product_barcode': '61331044',
#   'amount_spent': '68.44'},
#  {'transaction_date': '2021-01-05',
#   'name': 'Eric Green',
#   'gender': 'F',
#   'email': 'jorge90@hotmail.com',
#   'city': 'Frankview',
#   'product_barcode': '48462990',
#   'amount_spent': '96.89'},
#  {'transaction_date': '2021-09-22',
#   'name': 'Julia Dyer',
#   'gender': 'F',
#   'email': 'davismargaret@smith.com',
#   'city': 'North Sandraburgh',
#   'product_barcode': '76436819',
#   'amount_spent': '77.64'},
#  {'transaction_date': '2021-07-27',
#   'name': 'Carrie Roberts',
#   'gender': 'M',
#   'email': 'ashleyspencer@gutierrez.com',
#   'city': 'Sherrychester',
#   'product_barcode': '37532321',
#   'amount_spent': '55.8'},
#  {'transaction_date': '2021-10-25',
#   'name': 'Michael Manning',
#   'gender': 'F',
#   'email': 'merrittemily@reynolds.net',
#   'city': 'Port Barbarahaven',
#   'product_barcode': '77430502',
#   'amount_spent': '12.82'},
#  {'transaction_date': '2021-11-30',
#   'name': 'Laura Bridges',
#   'gender': 'F',
#   'email': 'zgordon@murphy-baker.info',
#   'city': 'North Kathyshire',
#   'product_barcode': '95927541',
#   'amount_spent': '67.3'},
#  {'transaction_date': '2021-01-08',
#   'name': 'Cheryl Lee',
#   'gender': 'M',
#   'email': 'caitlinbush@peterson-pollard.biz',
#   'city': 'Lake Tiffanyview',
#   'product_barcode': '11682660',
#   'amount_spent': '80.98'},
#  {'transaction_date': '2021-04-26',
#   'name': 'Eric Hancock',
#   'gender': 'M',
#   'email': 'ikeller@yahoo.com',
#   'city': 'Colebury',
#   'product_barcode': '35647782',
#   'amount_spent': '44.72'},
#  {'transaction_date': '2021-10-20',
#   'name': 'Joel Berry',
#   'gender': 'M',
#   'email': 'victorsmith@hayes-delgado.com',
#   'city': 'Port Mark',
#   'product_barcode': '31801034',
#   'amount_spent': '97.96'},
#  {'transaction_date': '2021-04-22',
#   'name': 'David Morrison',
#   'gender': 'F',
#   'email': 'abarrett@espinoza-webb.net',
#   'city': 'East Melanie',
#   'product_barcode': '74342709',
#   'amount_spent': '10.6'},
#  {'transaction_date': '2021-04-27',
#   'name': 'Courtney Ortega',
#   'gender': 'F',
#   'email': 'jeffrey94@hotmail.com',
#   'city': 'Kristiville',
#   'product_barcode': '93345552',
#   'amount_spent': '6.55'},
#  {'transaction_date': '2021-06-09',
#   'name': 'Michael Byrd',
#   'gender': 'F',
#   'email': 'ole@yahoo.com',
#   'city': 'Thomasborough',
#   'product_barcode': '43322374',
#   'amount_spent': '86.81'},
#  {'transaction_date': '2021-05-23',
#   'name': 'Lori Carter',
#   'gender': 'F',
#   'email': 'allentyrone@reese.com',
#   'city': 'Mccarthychester',
#   'product_barcode': '21845147',
#   'amount_spent': '48.57'},
#  {'transaction_date': '2021-10-03',
#   'name': 'Joseph Adams',
#   'gender': 'M',
#   'email': 'jacobstewart@montgomery-khan.com',
#   'city': 'East Phyllisville',
#   'product_barcode': '40886732',
#   'amount_spent': '62.5'},
#  {'transaction_date': '2021-01-07',
#   'name': 'Brianna Yang',
#   'gender': 'F',
#   'email': 'dfuentes@li.com',
#   'city': 'Wilsonmouth',
#   'product_barcode': '47727694',
#   'amount_spent': '32.23'},
#  {'transaction_date': '2021-10-22',
#   'name': 'Ryan Riggs',
#   'gender': 'F',
#   'email': 'kwright@hotmail.com',
#   'city': 'New Brandon',
#   'product_barcode': '52643095',
#   'amount_spent': '94.47'},
#  {'transaction_date': '2021-10-06',
#   'name': 'Javier Short',
#   'gender': 'F',
#   'email': 'christopher28@hotmail.com',
#   'city': 'South Michaelchester',
#   'product_barcode': '78250260',
#   'amount_spent': '46.53'},
#  {'transaction_date': '2021-04-01',
#   'name': 'Mary Arnold',
#   'gender': 'F',
#   'email': 'savagephillip@hughes.com',
#   'city': 'North John',
#   'product_barcode': '67981038',
#   'amount_spent': '10.86'},
#  {'transaction_date': '2021-11-23',
#   'name': 'Jennifer Reeves',
#   'gender': 'M',
#   'email': 'smithsusan@hotmail.com',
#   'city': 'East Scottton',
#   'product_barcode': '10160954',
#   'amount_spent': '14.87'},
#  {'transaction_date': '2021-10-06',
#   'name': 'Sean Richards',
#   'gender': 'F',
#   'email': 'vickiwhite@crawford-miller.com',
#   'city': 'North Scott',
#   'product_barcode': '29470976',
#   'amount_spent': '53.29'},
#  {'transaction_date': '2021-07-14',
#   'name': 'Leslie Henson',
#   'gender': 'F',
#   'email': 'timothy11@daniel.org',
#   'city': 'Carlland',
#   'product_barcode': '07526022',
#   'amount_spent': '19.99'},
#  {'transaction_date': '2021-11-07',
#   'name': 'Lori Sanchez',
#   'gender': 'M',
#   'email': 'williamtorres@yahoo.com',
#   'city': 'Saraport',
#   'product_barcode': '55877992',
#   'amount_spent': '74.68'},
#  {'transaction_date': '2021-05-01',
#   'name': 'April Oneill',
#   'gender': 'F',
#   'email': 'spencerbonnie@yahoo.com',
#   'city': 'West Bradley',
#   'product_barcode': '13050979',
#   'amount_spent': '74.5'},
#  {'transaction_date': '2021-01-20',
#   'name': 'Darren Lambert',
#   'gender': 'M',
#   'email': 'lholland@hotmail.com',
#   'city': 'West Joseborough',
#   'product_barcode': '48522137',
#   'amount_spent': '61.99'},
#  {'transaction_date': '2021-04-24',
#   'name': 'Ashley James',
#   'gender': 'F',
#   'email': 'mendezashley@yahoo.com',
#   'city': 'Kevinbury',
#   'product_barcode': '96188613',
#   'amount_spent': '35.26'},
#  {'transaction_date': '2021-07-22',
#   'name': 'Monique Miller',
#   'gender': 'F',
#   'email': 'evansamy@davis-brooks.net',
#   'city': 'Lake Monica',
#   'product_barcode': '93183765',
#   'amount_spent': '87.57'},
#  {'transaction_date': '2021-05-30',
#   'name': 'Samuel Barton',
#   'gender': 'M',
#   'email': 'rsalazar@gmail.com',
#   'city': 'Port Amberview',
#   'product_barcode': '34952856',
#   'amount_spent': '25.9'},
#  {'transaction_date': '2021-10-21',
#   'name': 'Brittany Reed',
#   'gender': 'M',
#   'email': 'carol51@walker.com',
#   'city': 'South Sydney',
#   'product_barcode': '26797908',
#   'amount_spent': '18.88'},
#  {'transaction_date': '2021-11-21',
#   'name': 'Kayla Flores',
#   'gender': 'F',
#   'email': 'anthonyscott@hotmail.com',
#   'city': 'Littleton',
#   'product_barcode': '77705884',
#   'amount_spent': '65.45'},
#  {'transaction_date': '2021-08-26',
#   'name': 'Steve Young',
#   'gender': 'M',
#   'email': 'benjamindiaz@yahoo.com',
#   'city': 'New Melissa',
#   'product_barcode': '73959083',
#   'amount_spent': '3.56'},
#  {'transaction_date': '2021-10-19',
#   'name': 'Kerri Taylor',
#   'gender': 'F',
#   'email': 'randerson@gmail.com',
#   'city': 'South James',
#   'product_barcode': '11471783',
#   'amount_spent': '48.62'},
#  {'transaction_date': '2021-03-25',
#   'name': 'Emily Howard',
#   'gender': 'F',
#   'email': 'nguyenjessica@yahoo.com',
#   'city': 'Palmertown',
#   'product_barcode': '48228343',
#   'amount_spent': '79.36'},
#  {'transaction_date': '2021-01-03',
#   'name': 'April Ellis',
#   'gender': 'F',
#   'email': 'padillacarla@jones.com',
#   'city': 'New Benjamin',
#   'product_barcode': '34747506',
#   'amount_spent': '25.85'},
#  {'transaction_date': '2021-05-18',
#   'name': 'Paul Burnett',
#   'gender': 'M',
#   'email': 'anthonywilliams@morales-reyes.net',
#   'city': 'New Rebeccashire',
#   'product_barcode': '74021901',
#   'amount_spent': '19.74'},
#  {'transaction_date': '2021-03-18',
#   'name': 'Jeffrey Mcguire',
#   'gender': 'M',
#   'email': 'frederickgraham@smith.info',
#   'city': 'Aprilborough',
#   'product_barcode': '68163297',
#   'amount_spent': '67.32'},
#  {'transaction_date': '2021-02-27',
#   'name': 'Rodney Velasquez',
#   'gender': 'F',
#   'email': 'paulprice@allen.com',
#   'city': 'Port Cassandra',
#   'product_barcode': '22610607',
#   'amount_spent': '48.19'},
#  {'transaction_date': '2021-09-05',
#   'name': 'Alex Harris',
#   'gender': 'M',
#   'email': 'collierlori@williams.biz',
#   'city': 'Smithmouth',
#   'product_barcode': '60374707',
#   'amount_spent': '82.4'},
#  {'transaction_date': '2021-03-28',
#   'name': 'John White',
#   'gender': 'M',
#   'email': 'melaniemendoza@yahoo.com',
#   'city': 'South Gary',
#   'product_barcode': '28202431',
#   'amount_spent': '17.28'},
#  {'transaction_date': '2021-08-01',
#   'name': 'Troy Rosario',
#   'gender': 'F',
#   'email': 'mmcbride@gmail.com',
#   'city': 'East Kimberly',
#   'product_barcode': '15220851',
#   'amount_spent': '47.62'},
#  {'transaction_date': '2021-10-03',
#   'name': 'Lacey Perez',
#   'gender': 'M',
#   'email': 'smithanthony@yahoo.com',
#   'city': 'Port Albert',
#   'product_barcode': '35785583',
#   'amount_spent': '61.5'},
#  {'transaction_date': '2021-07-07',
#   'name': 'Stephanie Nielsen',
#   'gender': 'M',
#   'email': 'sarah87@gmail.com',
#   'city': 'Anthonymouth',
#   'product_barcode': '31866859',
#   'amount_spent': '25.95'},
#  {'transaction_date': '2021-07-21',
#   'name': 'Daniel Davis',
#   'gender': 'F',
#   'email': 'guerrerojaime@hotmail.com',
#   'city': 'West Barbara',
#   'product_barcode': '36253470',
#   'amount_spent': '50.92'},
#  {'transaction_date': '2021-07-11',
#   'name': 'Martin Lopez',
#   'gender': 'F',
#   'email': 'daniel06@yahoo.com',
#   'city': 'Lake Robertshire',
#   'product_barcode': '69690747',
#   'amount_spent': '12.29'},
#  {'transaction_date': '2021-07-11',
#   'name': 'Christine Chavez',
#   'gender': 'M',
#   'email': 'williamwise@hotmail.com',
#   'city': 'Kentburgh',
#   'product_barcode': '32833256',
#   'amount_spent': '45.95'},
#  {'transaction_date': '2021-06-20',
#   'name': 'Richard Mitchell',
#   'gender': 'F',
#   'email': 'smithkyle@yahoo.com',
#   'city': 'East Daniel',
#   'product_barcode': '00671774',
#   'amount_spent': '89.61'},
#  {'transaction_date': '2021-12-13',
#   'name': 'Tanner Johnson',
#   'gender': 'F',
#   'email': 'ukeith@hotmail.com',
#   'city': 'Lake Kara',
#   'product_barcode': '86352918',
#   'amount_spent': '15.84'},
#  {'transaction_date': '2021-04-04',
#   'name': 'Melissa Hardy',
#   'gender': 'F',
#   'email': 'jennifer44@scott.info',
#   'city': 'Jonesborough',
#   'product_barcode': '32216479',
#   'amount_spent': '65.61'},
#  {'transaction_date': '2021-07-18',
#   'name': 'Robert Morrison',
#   'gender': 'F',
#   'email': 'linda34@beard-hill.com',
#   'city': 'Lisamouth',
#   'product_barcode': '50030538',
#   'amount_spent': '41.91'},
#  {'transaction_date': '2021-05-01',
#   'name': 'Roger Davis',
#   'gender': 'M',
#   'email': 'ggray@hotmail.com',
#   'city': 'Manuelchester',
#   'product_barcode': '36808250',
#   'amount_spent': '71.14'},
#  {'transaction_date': '2021-01-30',
#   'name': 'Nicholas Smith',
#   'gender': 'F',
#   'email': 'jamesduke@james.info',
#   'city': 'Garciahaven',
#   'product_barcode': '79255257',
#   'amount_spent': '72.12'},
#  {'transaction_date': '2021-11-25',
#   'name': 'Frederick Miller',
#   'gender': 'M',
#   'email': 'megan42@shields.info',
#   'city': 'Lake Heather',
#   'product_barcode': '33302928',
#   'amount_spent': '78.62'},
#  {'transaction_date': '2021-12-13',
#   'name': 'Brittany Oneal',
#   'gender': 'M',
#   'email': 'stodd@lopez.net',
#   'city': 'West David',
#   'product_barcode': '57279589',
#   'amount_spent': '21.22'},
#  {'transaction_date': '2021-10-06',
#   'name': 'Dawn Sweeney',
#   'gender': 'F',
#   'email': 'debbiemarquez@gmail.com',
#   'city': 'Lake Mark',
#   'product_barcode': '02470771',
#   'amount_spent': '59.69'},
#  {'transaction_date': '2021-05-14',
#   'name': 'Michael Gonzalez',
#   'gender': 'F',
#   'email': 'williamnorris@yahoo.com',
#   'city': 'West Tracey',
#   'product_barcode': '00779623',
#   'amount_spent': '18.79'},
#  {'transaction_date': '2021-07-18',
#   'name': 'Carrie Bruce',
#   'gender': 'M',
#   'email': 'daniel78@hotmail.com',
#   'city': 'Ariasland',
#   'product_barcode': '48623803',
#   'amount_spent': '7.75'},
#  {'transaction_date': '2021-07-08',
#   'name': 'Malik Hernandez',
#   'gender': 'M',
#   'email': 'alan98@yahoo.com',
#   'city': 'Port Aaron',
#   'product_barcode': '73938408',
#   'amount_spent': '46.0'},
#  {'transaction_date': '2021-10-16',
#   'name': 'Paul Garcia',
#   'gender': 'M',
#   'email': 'nunezdeanna@hotmail.com',
#   'city': 'Wallacefurt',
#   'product_barcode': '56963311',
#   'amount_spent': '98.2'},
#  {'transaction_date': '2021-02-21',
#   'name': 'Anthony Johnson',
#   'gender': 'M',
#   'email': 'jacquelinegriffin@bennett.biz',
#   'city': 'East Mariahaven',
#   'product_barcode': '95626109',
#   'amount_spent': '28.0'},
#  {'transaction_date': '2021-02-20',
#   'name': 'Anthony Rose',
#   'gender': 'M',
#   'email': 'patrick71@hotmail.com',
#   'city': 'Jillside',
#   'product_barcode': '36428861',
#   'amount_spent': '86.32'},
#  {'transaction_date': '2021-11-26',
#   'name': 'Tony Medina',
#   'gender': 'F',
#   'email': 'kelly76@brown.com',
#   'city': 'South Juanville',
#   'product_barcode': '63866476',
#   'amount_spent': '85.42'},
#  {'transaction_date': '2021-06-19',
#   'name': 'Juan Rowe',
#   'gender': 'F',
#   'email': 'adamgoodwin@yates.org',
#   'city': 'Michelleside',
#   'product_barcode': '21766473',
#   'amount_spent': '55.26'},
#  {'transaction_date': '2021-08-02',
#   'name': 'Roger Ford',
#   'gender': 'M',
#   'email': 'stephen86@pratt.com',
#   'city': 'Brianview',
#   'product_barcode': '19650470',
#   'amount_spent': '16.7'},
#  {'transaction_date': '2021-12-06',
#   'name': 'Cassandra Castillo',
#   'gender': 'F',
#   'email': 'charles55@yahoo.com',
#   'city': 'New Jennifer',
#   'product_barcode': '48593090',
#   'amount_spent': '11.9'},
#  {'transaction_date': '2021-07-10',
#   'name': 'Shannon Arnold',
#   'gender': 'M',
#   'email': 'fwilliams@gmail.com',
#   'city': 'Kelseyshire',
#   'product_barcode': '68657772',
#   'amount_spent': '73.18'},
#  {'transaction_date': '2021-05-21',
#   'name': 'John Short',
#   'gender': 'F',
#   'email': 'bholmes@sheppard.com',
#   'city': 'Barrerafurt',
#   'product_barcode': '38008184',
#   'amount_spent': '16.11'},
#  {'transaction_date': '2021-03-24',
#   'name': 'Jessica Barker',
#   'gender': 'F',
#   'email': 'beth00@yahoo.com',
#   'city': 'Lake Sean',
#   'product_barcode': '52416576',
#   'amount_spent': '10.5'},
#  {'transaction_date': '2021-03-08',
#   'name': 'Jeffrey Gibson',
#   'gender': 'M',
#   'email': 'beverlyjacobs@howard.info',
#   'city': 'East Tyler',
#   'product_barcode': '65831939',
#   'amount_spent': '70.68'},
#  {'transaction_date': '2021-10-27',
#   'name': 'Joshua Davis',
#   'gender': 'F',
#   'email': 'ybarnes@yahoo.com',
#   'city': 'New Erikside',
#   'product_barcode': '47922549',
#   'amount_spent': '12.86'},
#  {'transaction_date': '2021-06-29',
#   'name': 'Mr. Ryan Moreno MD',
#   'gender': 'F',
#   'email': 'wattsjodi@yahoo.com',
#   'city': 'East Ericaborough',
#   'product_barcode': '51710453',
#   'amount_spent': '47.45'},
#  {'transaction_date': '2021-07-11',
#   'name': 'Ellen Mcintyre',
#   'gender': 'F',
#   'email': 'jacksonchristine@robinson.biz',
#   'city': 'Port Rebecca',
#   'product_barcode': '81972531',
#   'amount_spent': '77.34'},
#  {'transaction_date': '2021-06-13',
#   'name': 'Hannah Sanford',
#   'gender': 'F',
#   'email': 'ddowns@hotmail.com',
#   'city': 'Robertmouth',
#   'product_barcode': '92043657',
#   'amount_spent': '6.48'},
#  {'transaction_date': '2021-01-18',
#   'name': 'Wendy Guzman',
#   'gender': 'M',
#   'email': 'kevin08@yahoo.com',
#   'city': 'East Robertside',
#   'product_barcode': '69904561',
#   'amount_spent': '84.12'},
#  {'transaction_date': '2021-08-15',
#   'name': 'Caroline Lopez',
#   'gender': 'F',
#   'email': 'jonathan99@gmail.com',
#   'city': 'Port Amber',
#   'product_barcode': '89721568',
#   'amount_spent': '23.19'},
#  {'transaction_date': '2021-09-18',
#   'name': 'Brandon Watts',
#   'gender': 'M',
#   'email': 'thomasthompson@manning-thompson.net',
#   'city': 'East Gary',
#   'product_barcode': '92896055',
#   'amount_spent': '66.18'},
#  {'transaction_date': '2021-08-25',
#   'name': 'Michael Hernandez',
#   'gender': 'F',
#   'email': 'howarderika@yahoo.com',
#   'city': 'Mitchellview',
#   'product_barcode': '33307022',
#   'amount_spent': '50.35'},
#  {'transaction_date': '2021-08-27',
#   'name': 'Kimberly Garcia',
#   'gender': 'F',
#   'email': 'jose44@hotmail.com',
#   'city': 'Port Stephanie',
#   'product_barcode': '08481399',
#   'amount_spent': '34.76'},
#  {'transaction_date': '2021-11-02',
#   'name': 'Mr. Kevin Finley',
#   'gender': 'M',
#   'email': 'howardamy@yahoo.com',
#   'city': 'West Daniellefurt',
#   'product_barcode': '20591601',
#   'amount_spent': '37.78'},
#  {'transaction_date': '2021-06-20',
#   'name': 'Frank Harmon',
#   'gender': 'M',
#   'email': 'drew57@baxter.com',
#   'city': 'Schneiderstad',
#   'product_barcode': '24922579',
#   'amount_spent': '44.79'},
#  {'transaction_date': '2021-11-18',
#   'name': 'Debbie Camacho',
#   'gender': 'M',
#   'email': 'kim58@roberts.com',
#   'city': 'Maloneview',
#   'product_barcode': '26862125',
#   'amount_spent': '70.98'},
#  {'transaction_date': '2021-08-25',
#   'name': 'Thomas Mahoney',
#   'gender': 'F',
#   'email': 'loneill@spencer.com',
#   'city': 'Reynoldsmouth',
#   'product_barcode': '51567224',
#   'amount_spent': '40.56'},
#  {'transaction_date': '2021-05-27',
#   'name': 'Jordan Hoover',
#   'gender': 'M',
#   'email': 'jcarter@phillips.com',
#   'city': 'New Tina',
#   'product_barcode': '82115401',
#   'amount_spent': '65.89'},
#  {'transaction_date': '2021-09-29',
#   'name': 'Amber Kennedy',
#   'gender': 'F',
#   'email': 'dgates@baker-vargas.com',
#   'city': 'Nguyenville',
#   'product_barcode': '23813199',
#   'amount_spent': '48.52'},
#  {'transaction_date': '2021-06-14',
#   'name': 'Lisa Richards',
#   'gender': 'F',
#   'email': 'hayeselizabeth@hotmail.com',
#   'city': 'Lake Joseph',
#   'product_barcode': '76126505',
#   'amount_spent': '11.78'},
#  {'transaction_date': '2021-08-30',
#   'name': 'Anthony Mclaughlin',
#   'gender': 'F',
#   'email': 'tbarry@ramirez.org',
#   'city': 'New Danielhaven',
#   'product_barcode': '55634830',
#   'amount_spent': '98.77'},
#  {'transaction_date': '2021-07-02',
#   'name': 'Barbara King',
#   'gender': 'M',
#   'email': 'carlos04@gallagher-white.net',
#   'city': 'East Chelsea',
#   'product_barcode': '41812945',
#   'amount_spent': '99.25'},
#  {'transaction_date': '2021-03-25',
#   'name': 'Thomas Phillips',
#   'gender': 'F',
#   'email': 'laura16@yahoo.com',
#   'city': 'East Barbarabury',
#   'product_barcode': '83689659',
#   'amount_spent': '25.68'},
#  {'transaction_date': '2021-07-26',
#   'name': 'Daniel Dougherty',
#   'gender': 'M',
#   'email': 'ialexander@norris.org',
#   'city': 'Port Jimmyshire',
#   'product_barcode': '35671794',
#   'amount_spent': '64.55'},
#  {'transaction_date': '2021-10-28',
#   'name': 'Dan Ruiz',
#   'gender': 'M',
#   'email': 'lrichardson@gmail.com',
#   'city': 'Lake Williamview',
#   'product_barcode': '11098447',
#   'amount_spent': '68.65'},
#  {'transaction_date': '2021-05-11',
#   'name': 'Donald James',
#   'gender': 'F',
#   'email': 'regina62@miller-johns.com',
#   'city': 'New Kevinton',
#   'product_barcode': '67157938',
#   'amount_spent': '29.84'},
#  {'transaction_date': '2021-04-22',
#   'name': 'Brett Oconnor',
#   'gender': 'F',
#   'email': 'huffjared@smith.com',
#   'city': 'Torresland',
#   'product_barcode': '30681699',
#   'amount_spent': '42.24'},
#  {'transaction_date': '2021-02-18',
#   'name': 'Jeremy Lopez',
#   'gender': 'M',
#   'email': 'deanshepherd@graham-hodges.org',
#   'city': 'Lake Mitchell',
#   'product_barcode': '37698416',
#   'amount_spent': '55.76'},
#  {'transaction_date': '2021-08-04',
#   'name': 'Jessica Johnson',
#   'gender': 'M',
#   'email': 'patricia51@yahoo.com',
#   'city': 'Ashleyfort',
#   'product_barcode': '75756635',
#   'amount_spent': '29.85'},
#  {'transaction_date': '2021-06-04',
#   'name': 'Angela Kane',
#   'gender': 'M',
#   'email': 'madelineschultz@gmail.com',
#   'city': 'Richardberg',
#   'product_barcode': '96464229',
#   'amount_spent': '79.77'},
#  {'transaction_date': '2021-10-24',
#   'name': 'Anthony Mcdaniel',
#   'gender': 'F',
#   'email': 'johnsonjacob@davis.com',
#   'city': 'East Dianemouth',
#   'product_barcode': '91658784',
#   'amount_spent': '60.32'},
#  {'transaction_date': '2021-12-01',
#   'name': 'Hannah Young',
#   'gender': 'M',
#   'email': 'sallywoodward@henderson.info',
#   'city': 'Kelseytown',
#   'product_barcode': '96983225',
#   'amount_spent': '84.1'},
#  {'transaction_date': '2021-01-14',
#   'name': 'Jerome Hernandez',
#   'gender': 'F',
#   'email': 'alison33@yahoo.com',
#   'city': 'Kellyside',
#   'product_barcode': '95734453',
#   'amount_spent': '89.91'},
#  {'transaction_date': '2021-10-18',
#   'name': 'Lori Stevens',
#   'gender': 'M',
#   'email': 'plopez@weiss-watson.com',
#   'city': 'Port Ashley',
#   'product_barcode': '02299570',
#   'amount_spent': '11.5'},
#  {'transaction_date': '2021-01-14',
#   'name': 'Marcus Cochran',
#   'gender': 'F',
#   'email': 'amy78@smith-williams.com',
#   'city': 'Lake Isaac',
#   'product_barcode': '72624319',
#   'amount_spent': '19.23'},
#  {'transaction_date': '2021-10-15',
#   'name': 'Corey Lee',
#   'gender': 'M',
#   'email': 'hburke@weeks.com',
#   'city': 'Lake Michelleland',
#   'product_barcode': '78235311',
#   'amount_spent': '86.81'},
#  {'transaction_date': '2021-06-02',
#   'name': 'Ronald Johnson',
#   'gender': 'M',
#   'email': 'dana50@yahoo.com',
#   'city': 'East Brookeside',
#   'product_barcode': '58376041',
#   'amount_spent': '62.66'},
#  {'transaction_date': '2021-09-22',
#   'name': 'Mary Avila',
#   'gender': 'F',
#   'email': 'tyler91@gmail.com',
#   'city': 'Batesstad',
#   'product_barcode': '74185351',
#   'amount_spent': '50.22'},
#  {'transaction_date': '2021-07-21',
#   'name': 'Mark Herrera',
#   'gender': 'F',
#   'email': 'brandy66@yahoo.com',
#   'city': 'Morganmouth',
#   'product_barcode': '75686987',
#   'amount_spent': '15.6'},
#  {'transaction_date': '2021-06-23',
#   'name': 'Johnny Silva',
#   'gender': 'F',
#   'email': 'reedjordan@rodriguez.biz',
#   'city': 'Campbellport',
#   'product_barcode': '01724929',
#   'amount_spent': '98.29'},
#  {'transaction_date': '2021-09-26',
#   'name': 'Jacqueline Rodriguez',
#   'gender': 'M',
#   'email': 'florescolleen@gmail.com',
#   'city': 'Port Sarahshire',
#   'product_barcode': '70637878',
#   'amount_spent': '13.71'},
#  {'transaction_date': '2021-05-28',
#   'name': 'Katelyn Rosario',
#   'gender': 'M',
#   'email': 'miranda35@johnson.com',
#   'city': 'Galvanmouth',
#   'product_barcode': '10294598',
#   'amount_spent': '84.17'},
#  {'transaction_date': '2021-10-26',
#   'name': 'Daniel Nunez',
#   'gender': 'M',
#   'email': 'reyesmelinda@yahoo.com',
#   'city': 'New Michaelbury',
#   'product_barcode': '46738158',
#   'amount_spent': '25.83'},
#  {'transaction_date': '2021-12-10',
#   'name': 'Madeline Price',
#   'gender': 'F',
#   'email': 'dawn48@yahoo.com',
#   'city': 'South Edward',
#   'product_barcode': '10724590',
#   'amount_spent': '95.85'},
#  {'transaction_date': '2021-07-01',
#   'name': 'Bonnie Trevino',
#   'gender': 'M',
#   'email': 'vegamichael@hotmail.com',
#   'city': 'Geraldfort',
#   'product_barcode': '42072324',
#   'amount_spent': '84.9'},
#  {'transaction_date': '2021-12-02',
#   'name': 'Kathleen Snyder',
#   'gender': 'F',
#   'email': 'ablanchard@yahoo.com',
#   'city': 'North Tamaraberg',
#   'product_barcode': '84269430',
#   'amount_spent': '60.34'},
#  {'transaction_date': '2021-01-23',
#   'name': 'Tammy Norton',
#   'gender': 'M',
#   'email': 'newmangarrett@gmail.com',
#   'city': 'East Laurietown',
#   'product_barcode': '87820218',
#   'amount_spent': '79.35'},
#  {'transaction_date': '2021-11-28',
#   'name': 'Laura Gilbert',
#   'gender': 'M',
#   'email': 'william76@lawrence.org',
#   'city': 'Everettbury',
#   'product_barcode': '78012103',
#   'amount_spent': '99.71'},
#  {'transaction_date': '2021-09-02',
#   'name': 'Jonathan Kennedy',
#   'gender': 'F',
#   'email': 'michael62@smith.com',
#   'city': 'Wallberg',
#   'product_barcode': '03096765',
#   'amount_spent': '39.93'},
#  {'transaction_date': '2021-08-06',
#   'name': 'Marcia Foster',
#   'gender': 'M',
#   'email': 'boliver@yahoo.com',
#   'city': 'North Jasonchester',
#   'product_barcode': '56545333',
#   'amount_spent': '25.33'},
#  {'transaction_date': '2021-11-04',
#   'name': 'Christopher Tate',
#   'gender': 'F',
#   'email': 'charlesandrews@walker.net',
#   'city': 'Amandaton',
#   'product_barcode': '67341719',
#   'amount_spent': '77.35'},
#  {'transaction_date': '2021-09-23',
#   'name': 'Douglas Welch',
#   'gender': 'F',
#   'email': 'holly91@gmail.com',
#   'city': 'New Roy',
#   'product_barcode': '50746262',
#   'amount_spent': '94.29'},
#  {'transaction_date': '2021-07-29',
#   'name': 'Tina Ballard',
#   'gender': 'M',
#   'email': 'christopher28@robertson.com',
#   'city': 'New Megan',
#   'product_barcode': '12454105',
#   'amount_spent': '85.12'},
#  {'transaction_date': '2021-01-16',
#   'name': 'Jason Davis',
#   'gender': 'M',
#   'email': 'ramirezjohn@hotmail.com',
#   'city': 'Coryside',
#   'product_barcode': '63307115',
#   'amount_spent': '50.72'},
#  {'transaction_date': '2021-07-09',
#   'name': 'Brenda Smith',
#   'gender': 'F',
#   'email': 'karen77@gmail.com',
#   'city': 'Thomasbury',
#   'product_barcode': '31197618',
#   'amount_spent': '91.24'},
#  {'transaction_date': '2021-01-23',
#   'name': 'Kelly Garza',
#   'gender': 'F',
#   'email': 'arielhayes@hotmail.com',
#   'city': 'Rodriguezstad',
#   'product_barcode': '56897531',
#   'amount_spent': '98.56'},
#  {'transaction_date': '2021-01-10',
#   'name': 'Brenda Garcia',
#   'gender': 'M',
#   'email': 'umccann@jones.com',
#   'city': 'West Kristin',
#   'product_barcode': '94514865',
#   'amount_spent': '32.39'},
#  {'transaction_date': '2021-10-04',
#   'name': 'Charles French',
#   'gender': 'M',
#   'email': 'larry11@yahoo.com',
#   'city': 'Lake Margaretside',
#   'product_barcode': '56370324',
#   'amount_spent': '66.35'},
#  {'transaction_date': '2021-08-05',
#   'name': 'Kenneth Jackson',
#   'gender': 'M',
#   'email': 'pamela49@hotmail.com',
#   'city': 'Johnsonfurt',
#   'product_barcode': '54082526',
#   'amount_spent': '48.79'},
#  {'transaction_date': '2021-03-25',
#   'name': 'Philip Williams',
#   'gender': 'M',
#   'email': 'jasminesavage@hotmail.com',
#   'city': 'North Brookeville',
#   'product_barcode': '73214441',
#   'amount_spent': '70.84'},
#  {'transaction_date': '2021-11-28',
#   'name': 'Michael Vargas',
#   'gender': 'F',
#   'email': 'calderonvalerie@gmail.com',
#   'city': 'Jonesstad',
#   'product_barcode': '22385017',
#   'amount_spent': '87.17'},
#  {'transaction_date': '2021-08-10',
#   'name': 'Michael Cooper',
#   'gender': 'M',
#   'email': 'xavila@hotmail.com',
#   'city': 'North Tamaraberg',
#   'product_barcode': '15397539',
#   'amount_spent': '70.64'},
#  {'transaction_date': '2021-05-16',
#   'name': 'Anna Charles',
#   'gender': 'M',
#   'email': 'michaelmartinez@hotmail.com',
#   'city': 'Joseside',
#   'product_barcode': '33602776',
#   'amount_spent': '31.79'},
#  {'transaction_date': '2021-09-16',
#   'name': 'Brian Jennings',
#   'gender': 'M',
#   'email': 'martinezapril@jenkins.org',
#   'city': 'Dawsonmouth',
#   'product_barcode': '09268241',
#   'amount_spent': '42.47'},
#  {'transaction_date': '2021-10-21',
#   'name': 'Angela Austin',
#   'gender': 'M',
#   'email': 'zrice@wright.com',
# ...
#   'city': 'Brownville',
#   'product_barcode': '89823781',
#   'amount_spent': '65.35'},
#  {'transaction_date': '2021-04-03',
#   'name': 'Brandon Raymond',
#   'gender': 'F',
#   'email': 'jhuang@evans.com',
#   'city': 'East Donton',
#   'product_barcode': '45072703',
#   'amount_spent': '74.57'},
#  {'transaction_date': '2021-11-06',
#   'name': 'David Wallace',
#   'gender': 'M',
#   'email': 'katherine31@gmail.com',
#   'city': 'North Jennifer',
#   'product_barcode': '11003304',
#   'amount_spent': '44.98'},
#  {'transaction_date': '2021-12-21',
#   'name': 'Mary Williamson',
#   'gender': 'F',
#   'email': 'wilsonlori@gmail.com',
#   'city': 'Elizabethtown',
#   'product_barcode': '39118936',
#   'amount_spent': '15.35'},
#  {'transaction_date': '2021-09-09',
#   'name': 'Jennifer Rowe',
#   'gender': 'F',
#   'email': 'whiteeugene@gmail.com',
#   'city': 'Chapmanshire',
#   'product_barcode': '75460044',
#   'amount_spent': '27.6'},
#  {'transaction_date': '2021-02-02',
#   'name': 'Melissa Watts',
#   'gender': 'M',
#   'email': 'alexandra93@gmail.com',
#   'city': 'New Bernard',
#   'product_barcode': '55800075',
#   'amount_spent': '28.13'},
#  {'transaction_date': '2021-11-27',
#   'name': 'Paul Carpenter',
#   'gender': 'M',
#   'email': 'gregorysalinas@gmail.com',
#   'city': 'New Caleb',
#   'product_barcode': '76968013',
#   'amount_spent': '44.37'},
#  {'transaction_date': '2021-06-19',
#   'name': 'Michael Jones',
#   'gender': 'M',
#   'email': 'reyeskarina@potts.biz',
#   'city': 'Port Angela',
#   'product_barcode': '94520392',
#   'amount_spent': '23.33'},
#  {'transaction_date': '2021-08-07',
#   'name': 'Raymond Little',
#   'gender': 'M',
#   'email': 'keithyoung@yahoo.com',
#   'city': 'Randallhaven',
#   'product_barcode': '60637642',
#   'amount_spent': '87.24'},
#  {'transaction_date': '2021-02-26',
#   'name': 'Becky Salazar',
#   'gender': 'M',
#   'email': 'cbrewer@hayes-hernandez.com',
#   'city': 'West Thomasview',
#   'product_barcode': '57193991',
#   'amount_spent': '6.52'},
#  {'transaction_date': '2021-04-26',
#   'name': 'Dustin Knight',
#   'gender': 'F',
#   'email': 'tlarson@hotmail.com',
#   'city': 'Michelletown',
#   'product_barcode': '39474360',
#   'amount_spent': '98.71'},
#  {'transaction_date': '2021-10-28',
#   'name': 'William Klein',
#   'gender': 'F',
#   'email': 'grimesjeremy@lucas-willis.com',
#   'city': 'Rodriguezborough',
#   'product_barcode': '38500435',
#   'amount_spent': '29.63'},
#  {'transaction_date': '2021-12-10',
#   'name': 'Elizabeth Jimenez',
#   'gender': 'F',
#   'email': 'owatkins@munoz-hoffman.com',
#   'city': 'East Lisa',
#   'product_barcode': '73655060',
#   'amount_spent': '79.69'},
#  {'transaction_date': '2021-06-11',
#   'name': 'Michael Reed',
#   'gender': 'F',
#   'email': 'zvasquez@yahoo.com',
#   'city': 'North Jamesside',
#   'product_barcode': '45189098',
#   'amount_spent': '75.36'},
#  {'transaction_date': '2021-05-29',
#   'name': 'Erin Nguyen',
#   'gender': 'F',
#   'email': 'amandaallen@dennis-mercado.com',
#   'city': 'North Mikayla',
#   'product_barcode': '99081935',
#   'amount_spent': '56.85'},
#  {'transaction_date': '2021-12-10',
#   'name': 'Kelly Smith MD',
#   'gender': 'M',
#   'email': 'carriedelacruz@yahoo.com',
#   'city': 'Port Rebecca',
#   'product_barcode': '03914199',
#   'amount_spent': '4.84'},
#  {'transaction_date': '2021-02-04',
#   'name': 'Christine Lee',
#   'gender': 'M',
#   'email': 'grice@yahoo.com',
#   'city': 'South Charles',
#   'product_barcode': '13839567',
#   'amount_spent': '15.9'},
#  {'transaction_date': '2021-01-08',
#   'name': 'Amanda Shaw',
#   'gender': 'M',
#   'email': 'heather46@gmail.com',
#   'city': 'North Cameronburgh',
#   'product_barcode': '95107066',
#   'amount_spent': '21.73'},
#  {'transaction_date': '2021-02-07',
#   'name': 'Jennifer Richardson',
#   'gender': 'F',
#   'email': 'mortonrichard@yahoo.com',
#   'city': 'Nicolefurt',
#   'product_barcode': '84493545',
#   'amount_spent': '6.61'},
#  {'transaction_date': '2021-03-25',
#   'name': 'Stephanie Johnson',
#   'gender': 'F',
#   'email': 'sarah87@gmail.com',
#   'city': 'North Mark',
#   'product_barcode': '24462143',
#   'amount_spent': '37.98'},
#  {'transaction_date': '2021-10-31',
#   'name': 'Gabriel Martinez',
#   'gender': 'F',
#   'email': 'antonio65@yahoo.com',
#   'city': 'Lake Joshuaport',
#   'product_barcode': '86195706',
#   'amount_spent': '80.33'},
#  {'transaction_date': '2021-08-27',
#   'name': 'Richard Parker',
#   'gender': 'M',
#   'email': 'scott93@hamilton.com',
#   'city': 'East Steven',
#   'product_barcode': '38089893',
#   'amount_spent': '75.88'},
#  {'transaction_date': '2021-02-02',
#   'name': 'Jeffery Daniels',
#   'gender': 'F',
#   'email': 'christina19@miller-campbell.com',
#   'city': 'Gregoryshire',
#   'product_barcode': '42764038',
#   'amount_spent': '6.22'},
#  {'transaction_date': '2021-09-23',
#   'name': 'Cynthia Williams',
#   'gender': 'M',
#   'email': 'kelsey45@hotmail.com',
#   'city': 'Port Deniseberg',
#   'product_barcode': '51608804',
#   'amount_spent': '47.41'},
#  {'transaction_date': '2021-12-06',
#   'name': 'Cheryl Rodriguez',
#   'gender': 'M',
#   'email': 'xwright@hotmail.com',
#   'city': 'Angelafort',
#   'product_barcode': '09773837',
#   'amount_spent': '24.2'},
#  {'transaction_date': '2021-08-31',
#   'name': 'Oscar Flores',
#   'gender': 'F',
#   'email': 'brittany75@yahoo.com',
#   'city': 'Port Cynthiaberg',
#   'product_barcode': '93129251',
#   'amount_spent': '6.68'},
#  {'transaction_date': '2021-11-28',
#   'name': 'Jamie Allen',
#   'gender': 'M',
#   'email': 'marissapeterson@mora-steele.net',
#   'city': 'Goodwinshire',
#   'product_barcode': '66965381',
#   'amount_spent': '84.56'},
#  {'transaction_date': '2021-02-11',
#   'name': 'David Buck',
#   'gender': 'F',
#   'email': 'baileykaren@gmail.com',
#   'city': 'South Scottmouth',
#   'product_barcode': '95143309',
#   'amount_spent': '19.47'},
#  {'transaction_date': '2021-03-03',
#   'name': 'Beth Hodges',
#   'gender': 'M',
#   'email': 'jhart@schneider.com',
#   'city': 'Rodriguezville',
#   'product_barcode': '93495158',
#   'amount_spent': '13.87'},
#  {'transaction_date': '2021-08-22',
#   'name': 'Kim Stevens',
#   'gender': 'M',
#   'email': 'barnettgerald@sosa.com',
#   'city': 'Joshuaside',
#   'product_barcode': '37967918',
#   'amount_spent': '15.81'},
#  {'transaction_date': '2021-10-19',
#   'name': 'Patrick Garcia',
#   'gender': 'F',
#   'email': 'huberkyle@gmail.com',
#   'city': 'West Holly',
#   'product_barcode': '97206477',
#   'amount_spent': '61.9'},
#  {'transaction_date': '2021-10-22',
#   'name': 'Patrick Norris',
#   'gender': 'M',
#   'email': 'biancasmith@gmail.com',
#   'city': 'Lake Elizabeth',
#   'product_barcode': '58797860',
#   'amount_spent': '88.59'},
#  {'transaction_date': '2021-06-23',
#   'name': 'Amber Lewis',
#   'gender': 'M',
#   'email': 'clarkdavid@munoz.net',
#   'city': 'New Kimberlyburgh',
#   'product_barcode': '85325852',
#   'amount_spent': '60.56'},
#  {'transaction_date': '2021-01-08',
#   'name': 'Randy Walsh',
#   'gender': 'M',
#   'email': 'perryjonathan@bates.com',
#   'city': 'Port Michaelport',
#   'product_barcode': '16704756',
#   'amount_spent': '50.61'},
#  {'transaction_date': '2021-06-13',
#   'name': 'Rebecca Jones',
#   'gender': 'F',
#   'email': 'thomas79@yahoo.com',
#   'city': 'Whiteview',
#   'product_barcode': '97263258',
#   'amount_spent': '27.29'},
#  {'transaction_date': '2021-09-15',
#   'name': 'Adam Crawford',
#   'gender': 'M',
#   'email': 'mitchelljean@gmail.com',
#   'city': 'North Mark',
#   'product_barcode': '19340777',
#   'amount_spent': '82.28'},
#  {'transaction_date': '2021-06-18',
#   'name': 'Kristi Barrera',
#   'gender': 'M',
#   'email': 'matthew89@gmail.com',
#   'city': 'Cannonhaven',
#   'product_barcode': '11419716',
#   'amount_spent': '62.62'},
#  {'transaction_date': '2021-02-22',
#   'name': 'Robert Clayton',
#   'gender': 'F',
#   'email': 'cynthia76@gmail.com',
#   'city': 'East Wyattberg',
#   'product_barcode': '61674851',
#   'amount_spent': '24.8'},
#  {'transaction_date': '2021-05-24',
#   'name': 'Debra Allen',
#   'gender': 'F',
#   'email': 'nicholschristopher@walsh.com',
#   'city': 'New Angelashire',
#   'product_barcode': '54667273',
#   'amount_spent': '65.43'},
#  {'transaction_date': '2021-06-03',
#   'name': 'Eugene Williams',
#   'gender': 'M',
#   'email': 'smithjeff@prince-burke.net',
#   'city': 'Michellehaven',
#   'product_barcode': '12646128',
#   'amount_spent': '82.87'},
#  {'transaction_date': '2021-07-19',
#   'name': 'Dawn Walker',
#   'gender': 'F',
#   'email': 'andre78@hotmail.com',
#   'city': 'New Jacquelineton',
#   'product_barcode': '98200481',
#   'amount_spent': '71.6'},
#  {'transaction_date': '2021-07-17',
#   'name': 'Sarah Mcdonald',
#   'gender': 'F',
#   'email': 'lisahodge@gmail.com',
#   'city': 'Webbberg',
#   'product_barcode': '36897827',
#   'amount_spent': '71.47'},
#  {'transaction_date': '2021-10-02',
#   'name': 'Emily Henderson',
#   'gender': 'M',
#   'email': 'michael88@gmail.com',
#   'city': 'Jonesmouth',
#   'product_barcode': '39831316',
#   'amount_spent': '78.53'},
#  {'transaction_date': '2021-06-02',
#   'name': 'Cindy Fox',
#   'gender': 'F',
#   'email': 'mercermonica@nelson-smith.net',
#   'city': 'Port Reginaldberg',
#   'product_barcode': '76768934',
#   'amount_spent': '25.43'},
#  {'transaction_date': '2021-10-24',
#   'name': 'Jacob Mcpherson',
#   'gender': 'M',
#   'email': 'sarah52@glass.com',
#   'city': 'Ginamouth',
#   'product_barcode': '48896498',
#   'amount_spent': '81.88'},
#  {'transaction_date': '2021-10-09',
#   'name': 'Jennifer Barnes',
#   'gender': 'F',
#   'email': 'upeters@gmail.com',
#   'city': 'Scotttown',
#   'product_barcode': '89399514',
#   'amount_spent': '65.62'},
#  {'transaction_date': '2021-08-20',
#   'name': 'John Medina',
#   'gender': 'M',
#   'email': 'stanleybarrera@yahoo.com',
#   'city': 'Port Stephanie',
#   'product_barcode': '90806667',
#   'amount_spent': '3.54'},
#  {'transaction_date': '2021-07-19',
#   'name': 'Megan Jackson',
#   'gender': 'F',
#   'email': 'jjennings@yahoo.com',
#   'city': 'Carolineburgh',
#   'product_barcode': '87172324',
#   'amount_spent': '20.98'},
#  {'transaction_date': '2021-03-10',
#   'name': 'James Conley',
#   'gender': 'M',
#   'email': 'ofisher@pennington.com',
#   'city': 'West Kathyview',
#   'product_barcode': '26251332',
#   'amount_spent': '64.38'},
#  {'transaction_date': '2021-05-18',
#   'name': 'Jordan Deleon',
#   'gender': 'F',
#   'email': 'hcallahan@jones.info',
#   'city': 'Port Jeremymouth',
#   'product_barcode': '64899053',
#   'amount_spent': '49.99'},
#  {'transaction_date': '2021-03-04',
#   'name': 'Molly Bradford',
#   'gender': 'M',
#   'email': 'ecole@yahoo.com',
#   'city': 'Dawnbury',
#   'product_barcode': '58001271',
#   'amount_spent': '89.88'},
#  {'transaction_date': '2021-01-31',
#   'name': 'Jessica Gibson',
#   'gender': 'M',
#   'email': 'stephenlivingston@hoffman.net',
#   'city': 'Tinastad',
#   'product_barcode': '51425029',
#   'amount_spent': '85.71'},
#  {'transaction_date': '2021-02-04',
#   'name': 'Christina Curtis',
#   'gender': 'F',
#   'email': 'tonyagray@yahoo.com',
#   'city': 'Carolmouth',
#   'product_barcode': '41075036',
#   'amount_spent': '79.31'},
#  {'transaction_date': '2021-05-03',
#   'name': 'Helen Mccarthy',
#   'gender': 'F',
#   'email': 'michellesmith@sanchez-cunningham.com',
#   'city': 'North Kevin',
#   'product_barcode': '23912472',
#   'amount_spent': '74.1'},
#  {'transaction_date': '2021-10-08',
#   'name': 'Virginia Heath',
#   'gender': 'F',
#   'email': 'david42@hotmail.com',
#   'city': 'North Robert',
#   'product_barcode': '95269054',
#   'amount_spent': '54.58'},
#  {'transaction_date': '2021-08-31',
#   'name': 'Jessica Carlson',
#   'gender': 'M',
#   'email': 'xkaufman@gmail.com',
#   'city': 'North Nicholas',
#   'product_barcode': '13683559',
#   'amount_spent': '84.89'},
#  {'transaction_date': '2021-07-07',
#   'name': 'Joseph Martinez',
#   'gender': 'F',
#   'email': 'mmccoy@simpson.com',
#   'city': 'Kaitlynfurt',
#   'product_barcode': '69665479',
#   'amount_spent': '49.24'},
#  {'transaction_date': '2021-10-07',
#   'name': 'Tonya Schneider',
#   'gender': 'M',
#   'email': 'wcoleman@hotmail.com',
#   'city': 'New Phillipview',
#   'product_barcode': '56205091',
#   'amount_spent': '60.62'},
#  {'transaction_date': '2021-05-01',
#   'name': 'Kari Pruitt',
#   'gender': 'F',
#   'email': 'kschultz@gmail.com',
#   'city': 'Andersenview',
#   'product_barcode': '11058564',
#   'amount_spent': '85.57'},
#  {'transaction_date': '2021-05-24',
#   'name': 'Corey Goodman',
#   'gender': 'F',
#   'email': 'friedmansara@kirk.com',
#   'city': 'New Adamfurt',
#   'product_barcode': '50434923',
#   'amount_spent': '64.2'},
#  {'transaction_date': '2021-02-21',
#   'name': 'Scott Gray',
#   'gender': 'F',
#   'email': 'tvaldez@yahoo.com',
#   'city': 'Hoganview',
#   'product_barcode': '02040608',
#   'amount_spent': '97.88'},
#  {'transaction_date': '2021-09-14',
#   'name': 'James Murphy',
#   'gender': 'M',
#   'email': 'amybradley@reed.net',
#   'city': 'Port Chad',
#   'product_barcode': '70807714',
#   'amount_spent': '6.23'},
#  {'transaction_date': '2021-04-19',
#   'name': 'Kathleen Anderson',
#   'gender': 'M',
#   'email': 'watsonsabrina@rodriguez-castro.biz',
#   'city': 'Woodburgh',
#   'product_barcode': '49874891',
#   'amount_spent': '87.56'},
#  {'transaction_date': '2021-06-16',
#   'name': 'Megan Martin',
#   'gender': 'F',
#   'email': 'nmitchell@gmail.com',
#   'city': 'North Nicoleton',
#   'product_barcode': '17280051',
#   'amount_spent': '2.22'},
#  {'transaction_date': '2021-04-05',
#   'name': 'John Wagner',
#   'gender': 'M',
#   'email': 'kathymartin@adams.net',
#   'city': 'Port Kimberly',
#   'product_barcode': '41742082',
#   'amount_spent': '25.21'},
#  {'transaction_date': '2021-05-04',
#   'name': 'Juan Le',
#   'gender': 'F',
#   'email': 'michellebrown@ray.biz',
#   'city': 'Acostaside',
#   'product_barcode': '22347473',
#   'amount_spent': '79.1'},
#  {'transaction_date': '2021-04-08',
#   'name': 'Mrs. Kristen Williams',
#   'gender': 'F',
#   'email': 'wlittle@wise-price.com',
#   'city': 'Amandabury',
#   'product_barcode': '53211675',
#   'amount_spent': '68.77'},
#  {'transaction_date': '2021-10-25',
#   'name': 'Jeremy King',
#   'gender': 'F',
#   'email': 'taylorrichard@yahoo.com',
#   'city': 'East Ashley',
#   'product_barcode': '19623368',
#   'amount_spent': '5.75'},
#  {'transaction_date': '2021-08-15',
#   'name': 'Jennifer Miller DVM',
#   'gender': 'F',
#   'email': 'tmclaughlin@gmail.com',
#   'city': 'Sharimouth',
#   'product_barcode': '17756709',
#   'amount_spent': '24.1'},
#  {'transaction_date': '2021-02-24',
#   'name': 'Eric Rodriguez',
#   'gender': 'M',
#   'email': 'dspencer@hotmail.com',
#   'city': 'Fordfort',
#   'product_barcode': '30906303',
#   'amount_spent': '69.11'},
#  {'transaction_date': '2021-03-14',
#   'name': 'Ryan Booth',
#   'gender': 'F',
#   'email': 'aaguilar@hickman.com',
#   'city': 'Natalieburgh',
#   'product_barcode': '52004629',
#   'amount_spent': '56.42'},
#  {'transaction_date': '2021-10-31',
#   'name': 'Tammy Ray',
#   'gender': 'M',
#   'email': 'larrywilliamson@hotmail.com',
#   'city': 'Leeborough',
#   'product_barcode': '36712250',
#   'amount_spent': '66.32'},
#  {'transaction_date': '2021-03-30',
#   'name': 'Carol Sims',
#   'gender': 'M',
#   'email': 'marygonzalez@hotmail.com',
#   'city': 'Huntborough',
#   'product_barcode': '86387361',
#   'amount_spent': '64.16'},
#  {'transaction_date': '2021-02-12',
#   'name': 'Terry Kim',
#   'gender': 'F',
#   'email': 'aaronbrandt@parker.com',
#   'city': 'West Matthewbury',
#   'product_barcode': '95465685',
#   'amount_spent': '35.85'},
#  {'transaction_date': '2021-11-09',
#   'name': 'Susan Rowe',
#   'gender': 'F',
#   'email': 'cmitchell@strickland.net',
#   'city': 'Foxberg',
#   'product_barcode': '96780848',
#   'amount_spent': '11.3'},
#  {'transaction_date': '2021-02-21',
#   'name': 'Whitney Hatfield',
#   'gender': 'F',
#   'email': 'jessicasullivan@chen-thompson.com',
#   'city': 'Jacktown',
#   'product_barcode': '28678311',
#   'amount_spent': '52.4'},
#  {'transaction_date': '2021-07-30',
#   'name': 'David Elliott',
#   'gender': 'M',
#   'email': 'thomasjackson@hotmail.com',
#   'city': 'Port Christinaton',
#   'product_barcode': '93353137',
#   'amount_spent': '19.44'},
#  {'transaction_date': '2021-10-14',
#   'name': 'Lisa Murphy',
#   'gender': 'M',
#   'email': 'lisa85@gmail.com',
#   'city': 'South Nicolemouth',
#   'product_barcode': '22775177',
#   'amount_spent': '18.12'},
#  {'transaction_date': '2021-09-03',
#   'name': 'Tracy Smith',
#   'gender': 'F',
#   'email': 'amanda54@thomas.biz',
#   'city': 'Hansonberg',
#   'product_barcode': '31129060',
#   'amount_spent': '63.2'}]

# %%
coll1.insert_many(customers_updated)

# %%
test_keys = ["Rash", "Kil", "Varsha"]
test_values = ['2021-04-20', 'Jacob Hayes', 'M']
  
# Printing original keys-value lists
print ("Original key list is : " + str(test_keys))
print ("Original value list is : " + str(test_values))
  
# using zip()
# to convert lists to dictionary
res = dict(zip(test_keys, test_values))
  
# Printing resultant dictionary 
print ("Resultant dictionary is : " +  str(res))
# Out:
# Original key list is : ['Rash', 'Kil', 'Varsha']
# Original value list is : ['2021-04-20', 'Jacob Hayes', 'M']
# Resultant dictionary is : {'Rash': '2021-04-20', 'Kil': 'Jacob Hayes', 'Varsha': 'M'}

# %%
coll1.find()

# %%
count = 0
for i in coll1.find({"transaction_date":{'$gt' : '2021-06-20'}, "gender":"F"}):
    count = count + 1

print(count)
# Out:
# 255

# %%
# db.users.find({"name": {"$regex": "string", "$options": "i"}})

count = 0
for i in coll1.find({"gender":"M", "name": {"$regex": "^m", "$options": "i"}}): #  /^m/
    count = count + 1

print(count)
# Out:
# 51
