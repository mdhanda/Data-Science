# %%
import pandas as pd

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
# read_html - limitations: always try to read the tabular format of data

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.tail
# Out:
# <bound method NDFrame.tail of       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]>

# %%
df1.to_csv('NBA.csv', index=False)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 24B2-47A3
#
#  Directory of C:\Users\Manu\iNeuron DataScience
#
# 05/03/2022  03:04 PM    <DIR>          .
# 05/03/2022  03:04 PM    <DIR>          ..
# 05/03/2022  03:03 PM    <DIR>          .ipynb_checkpoints
# 07/02/2022  05:44 PM            10,171 [Dec042021] Python Basic.ipynb
# 07/02/2022  05:01 PM            34,448 [Dec052021] Python Basic.ipynb
# 07/02/2022  10:52 PM            32,209 [Dec182021] Python Basic - Tuple, Set, Dict.ipynb
# 08/02/2022  10:23 PM            14,976 [Dec192021] Python Programming - Part 1.ipynb
# 06/02/2022  02:24 PM            59,153 [Feb052022] Basic SQL with Python.ipynb
# 06/02/2022  08:52 PM            37,343 [Feb062022] Advanced SQL with Python.ipynb
# 12/02/2022  06:38 PM            33,690 [Feb062022] Assignment Car Dataset.ipynb
# 13/02/2022  06:17 PM             2,153 [Feb122022].ipynb
# 19/02/2022  04:24 PM            19,196 [Feb132022] MongoDB.ipynb
# 23/02/2022  06:56 PM            13,585 [Feb192022] MongoDB Assignment - Carbon Nanotubes.ipynb
# 19/02/2022  04:43 PM            17,535 [Feb192022] MongoDB-Part 2.ipynb
# 23/02/2022  10:11 AM           495,946 [Feb202022] Assignment - Bag of words Dataset.ipynb
# 20/02/2022  06:44 PM            16,384 [Feb202022] SQLITE, MAP, FILTER, REDUCE, ZIP.ipynb
# 26/02/2022  04:53 PM             2,182 [Feb262022] Cassandra.ipynb
# 27/02/2022  03:47 PM            94,626 [Feb262022] Pandas Part 1.ipynb
# 05/03/2022  03:03 PM           594,276 [Feb272022] Pandas Part 2.ipynb
# 05/03/2022  03:04 PM            78,960 NBA.csv
#               17 File(s)      1,556,833 bytes
#                3 Dir(s)  254,442,819,584 bytes free

# %%
pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
# Out:
# [               Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
#  0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
#  1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
#  2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
#  3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
#  4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
#  ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
#  92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
#  93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
#  94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
#  95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
#  96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#     100 50  0  4s  6s
#  0    0  0  0   2   0
#  1    0  0  0   0   0
#  2    -  -  -   -   -
#  3    0  0  0  14   1
#  4    -  -  -   -   -
#  ..  .. .. ..  ..  ..
#  92   0  0  0   0   0
#  93   0  0  3   4   3
#  94   0  4  1  32  20
#  95   0  0  0   0   0
#  96   0  8  1  77  74
#
#  [97 rows x 15 columns],
#                                                     0
#  0  By default, the shading indicates records from...
#  1  Adjust:  most recent  | past week  | past mont...,
#                                                     0
#  0  Records includes the following current or rece...
#  1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
#  2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
#  3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...]

# %%
# How many tables on above link
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
l
# Out:
# [               Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
#  0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
#  1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
#  2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
#  3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
#  4          Avesh Khan  2022-2022    1    -  -     -    -      -    -       -
#  ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
#  92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
#  93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
#  94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
#  95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
#  96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#     100 50  0  4s  6s
#  0    0  0  0   2   0
#  1    0  0  0   0   0
#  2    -  -  -   -   -
#  3    0  0  0  14   1
#  4    -  -  -   -   -
#  ..  .. .. ..  ..  ..
#  92   0  0  0   0   0
#  93   0  0  3   4   3
#  94   0  4  1  32  20
#  95   0  0  0   0   0
#  96   0  8  1  77  74
#
#  [97 rows x 15 columns],
#                                                     0
#  0  By default, the shading indicates records from...
#  1  Adjust:  most recent  | past week  | past mont...,
#                                                     0
#  0  Records includes the following current or rece...
#  1  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
#  2  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...
#  3  India v West Indies at Kolkata, 3rd T20I, Feb ...]

# %%
l[0].to_csv('cricket.csv', index=False)

# %%
d="""
{
"name": "Manu Dhanda",
"email": "manu@email.com",
"tech": ["ML", "DL", "CV", "NLP", "RL", "BD", "DA"],
"platform": ["TechNeuron", "KidsNeuron", "iNeuron"]
}
"""
# I want to convert above in tabular format
# Above will not work, as item count in tech and platform are different

# %%
d="""
{
"name": "Manu Dhanda",
"email": "manu@email.com",
"tech": ["ML", "DL", "CV"],
"platform": ["TechNeuron", "KidsNeuron", "iNeuron"]
}
"""
# I want to convert above in tabular format

# %%
import json

# %%
result = json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#           name           email tech    platform
# 0  Manu Dhanda  manu@email.com   ML  TechNeuron
# 1  Manu Dhanda  manu@email.com   DL  KidsNeuron
# 2  Manu Dhanda  manu@email.com   CV     iNeuron

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
df = pd.read_json(url)

# %%
# Load just the raw json data
import requests

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
# 200 means success (HTTP protocols)
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46236',
#   'id': 1160198674,
#   'node_id': 'PR_kwDOAA0YD84z-8mt',
#   'number': 46236,
#   'title': 'troubleshoot 32bit build',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-05T02:51:25Z',
#   'updated_at': '2022-03-05T02:51:25Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46236',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46236',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46236.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46236.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46234',
#   'id': 1160089928,
#   'node_id': 'PR_kwDOAA0YD84z-mBc',
#   'number': 46234,
#   'title': 'REF: use standard pattern in _tz_convert_from_utc',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 60458168,
#     'node_id': 'MDU6TGFiZWw2MDQ1ODE2OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timezones',
#     'name': 'Timezones',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timezone data dtype'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 51,
#    'closed_issues': 445,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-05T01:17:43Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-03-04T22:07:03Z',
#   'updated_at': '2022-03-05T01:06:08Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46234',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46234',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46234.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46234.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAvoid unnecessary copy in non-UTC cases.\r\nConfirmed that the "TODO: How is this reached" case is not reachable, so removed it.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46232',
#   'id': 1160064471,
#   'node_id': 'PR_kwDOAA0YD84z-gzl',
#   'number': 46232,
#   'title': 'Adding overwrite or ignore behavior for row conflicts.',
#   'user': {'login': 'LSturtew',
#    'id': 56136443,
#    'node_id': 'MDQ6VXNlcjU2MTM2NDQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56136443?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LSturtew',
#    'html_url': 'https://github.com/LSturtew',
#    'followers_url': 'https://api.github.com/users/LSturtew/followers',
#    'following_url': 'https://api.github.com/users/LSturtew/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LSturtew/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LSturtew/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LSturtew/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LSturtew/orgs',
#    'repos_url': 'https://api.github.com/users/LSturtew/repos',
#    'events_url': 'https://api.github.com/users/LSturtew/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LSturtew/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T21:26:16Z',
#   'updated_at': '2022-03-04T21:26:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46232',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46232',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46232.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46232.patch',
#    'merged_at': None},
#   'body': "@cvonsteg started the effort to implement this. Since they are unable to continue and this is a highly desired feature, I made an attempt to clean up the code and fix merge conflicts. I would like to share the credit for this PR (I do not know how this works).\r\n\r\nA new parameter is added to `to_sql`: `on_row_conflct`\r\n\r\n    on_row_conflict : {'fail', 'overwrite', 'append'},\r\n        default: 'fail'\r\n        Determine insertion behavior in case of a primary key clash.\r\n        - 'fail': Do nothing to handle primary key clashes, will raise an Error.\r\n        - 'overwrite': Update existing rows in database with primary key clashes,\r\n          and append the remaining rows with non-conflicting primary keys\r\n        - 'append': Ignore incoming rows with primary key clashes, and\r\n          insert only the incoming rows with non-conflicting primary keys\r\n\r\n\r\n\r\n\r\n- [x] closes #14553, continuation of #29636\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46231',
#   'id': 1159934807,
#   'node_id': 'PR_kwDOAA0YD84z-FU6',
#   'number': 46231,
#   'title': 'DOC: Added plt.show() at the end of each necessary block',
#   'user': {'login': 'ehallam',
#    'id': 20362314,
#    'node_id': 'MDQ6VXNlcjIwMzYyMzE0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20362314?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ehallam',
#    'html_url': 'https://github.com/ehallam',
#    'followers_url': 'https://api.github.com/users/ehallam/followers',
#    'following_url': 'https://api.github.com/users/ehallam/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ehallam/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ehallam/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ehallam/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ehallam/orgs',
#    'repos_url': 'https://api.github.com/users/ehallam/repos',
#    'events_url': 'https://api.github.com/users/ehallam/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ehallam/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T18:36:18Z',
#   'updated_at': '2022-03-04T18:36:18Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46231',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46231',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46231.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46231.patch',
#    'merged_at': None},
#   'body': 'Moved title to the top of page and reworded title\r\n\r\n- [ ] closes #45772 \r\n- [x] ~[Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature~\r\n- [x] ~All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).~\r\n- [x] ~Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.~\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46230',
#   'id': 1159874789,
#   'node_id': 'I_kwDOAA0YD85FIkjl',
#   'number': 46230,
#   'title': 'BUG: pd.DataFrame.interpolate fails with ValueError: x and y arrays must have at least 2 entries',
#   'user': {'login': 'ianliu',
#    'id': 30196,
#    'node_id': 'MDQ6VXNlcjMwMTk2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30196?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ianliu',
#    'html_url': 'https://github.com/ianliu',
#    'followers_url': 'https://api.github.com/users/ianliu/followers',
#    'following_url': 'https://api.github.com/users/ianliu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ianliu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ianliu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ianliu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ianliu/orgs',
#    'repos_url': 'https://api.github.com/users/ianliu/repos',
#    'events_url': 'https://api.github.com/users/ianliu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ianliu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T17:19:14Z',
#   'updated_at': '2022-03-04T17:19:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport numpy as np\r\n\r\npd.DataFrame(dict(a=[np.nan, 1])).interpolate(method="nearest")\n```\n\n\n### Issue Description\n\nThe example fails with a Scipy exception which says:\r\n\r\n    ValueError: x and y arrays must have at least 2 entries\r\n\r\nThe following examples all work as intended:\r\n\r\n```python\r\n>>> pd.DataFrame(dict(a=[np.nan])).interpolate(method="nearest")\r\n#     a\r\n# 0 NaN\r\n\r\n>>> pd.DataFrame(dict(a=[np.nan, np.nan])).interpolate(method="nearest")\r\n#     a\r\n# 0 NaN\r\n# 1 NaN\r\n\r\n>>> pd.DataFrame(dict(a=[np.nan, 1, 1 np.nan])).interpolate(method="nearest")\r\n#     a\r\n# 0 NaN\r\n# 1 1.0\r\n# 2 1.0\r\n# 3 NaN\r\n```\n\n### Expected Behavior\n\n```python\r\n>>> pd.DataFrame(dict(a=[np.nan, 1])).interpolate(method="nearest")\r\n#     a\r\n# 0 NaN\r\n# 1 1.0\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.10.2.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.16.12-arch1-1\r\nVersion          : #1 SMP PREEMPT Wed, 02 Mar 2022 12:22:51 +0000\r\nmachine          : x86_64\r\nprocessor        : \r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 21.0\r\nsetuptools       : 59.3.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : 4.4.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.7.1\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.0.3\r\nIPython          : 8.1.0\r\npandas_datareader: 0.10.0\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : 2021.10.1\r\ngcsfs            : None\r\nmatplotlib       : 3.5.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 6.0.1\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.0\r\nsqlalchemy       : 1.4.30\r\ntables           : None\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46229',
#   'id': 1159791857,
#   'node_id': 'I_kwDOAA0YD85FIQTx',
#   'number': 46229,
#   'title': 'BUG: ',
#   'user': {'login': 'raffaem',
#    'id': 54762742,
#    'node_id': 'MDQ6VXNlcjU0NzYyNzQy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54762742?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raffaem',
#    'html_url': 'https://github.com/raffaem',
#    'followers_url': 'https://api.github.com/users/raffaem/followers',
#    'following_url': 'https://api.github.com/users/raffaem/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/raffaem/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/raffaem/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/raffaem/subscriptions',
#    'organizations_url': 'https://api.github.com/users/raffaem/orgs',
#    'repos_url': 'https://api.github.com/users/raffaem/repos',
#    'events_url': 'https://api.github.com/users/raffaem/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/raffaem/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-04T15:54:29Z',
#   'updated_at': '2022-03-05T00:44:21Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nI\'m calling this on a .csv file:\r\n\r\n```python\r\n\r\n#!/usr/bin/env python3\r\n\r\nimport pandas as pd\r\nimport sys\r\n\r\ninfp = sys.argv[1]\r\noutfp = infp.replace(".csv",".dta")\r\ndf = pd.read_csv(infp, header=0, low_memory=False) \r\ndf.to_stata(outfp, version=118, write_index=False)\r\n```\r\n\r\n### Issue Description\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "/run/media/raffaele/55ab61c4-83cf-4d9f-a5cd-7fcfdc14b4fb/data/progetti_miei/various_tools/csv2dta", line 9, in <module>\r\n    df.to_stata(outfp, version=118, write_index=False)\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/util/_decorators.py", line 207, in wrapper\r\n    return func(*args, **kwargs)\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/core/frame.py", line 2652, in to_stata\r\n    writer.write_file()\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 2659, in write_file\r\n    raise exc\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 2639, in write_file\r\n    records = self._prepare_data()\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 2827, in _prepare_data\r\n    data = self._convert_strls(data)\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 3454, in _convert_strls\r\n    self._strl_blob = ssw.generate_blob(tab)\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 3081, in generate_blob\r\n    utf8_string = bytes(strl, "utf-8")\r\nTypeError: encoding without a string argument\r\n```\r\n\r\n### Expected Behavior\r\n\r\nShould not raise an exception\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n>>> pd.show_versions()\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.10.2.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.16.10-200.fc35.x86_64\r\nVersion          : #1 SMP PREEMPT Wed Feb 16 13:28:00 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.1\r\npip              : 21.2.3\r\nsetuptools       : 57.4.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.7.1\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.1\r\nIPython          : 7.29.0\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.5.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.9\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.0\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46227',
#   'id': 1159657724,
#   'node_id': 'PR_kwDOAA0YD84z9LNE',
#   'number': 46227,
#   'title': 'DOC: migrate from sphinx-panels to sphinx-design',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T13:39:17Z',
#   'updated_at': '2022-03-04T13:39:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46227',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46227',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46227.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46227.patch',
#    'merged_at': None},
#   'body': 'Eventually it is the goal that the sphinx-design package replaces the sphinx-panels package (see https://github.com/executablebooks/sphinx-panels/issues/67 and https://sphinx-design.readthedocs.io/en/furo-theme/get_started.html#migrating-from-sphinx-panels, sphinx-design has the same (and more) features, but with a refactored and more flexible code base). \r\n\r\nSo this PR moves our usage of sphinx-panels to sphinx-design (at least already for the front page, still need to do the same for the getting started pages)\r\n\r\nIt gives almost identical result as we have now (screenshot is with this PR, compare with eg https://pandas.pydata.org/pandas-docs/version/1.3/):\r\n\r\n![image](https://user-images.githubusercontent.com/1020496/156773002-735b352e-26ad-408e-b792-9f3325f2e277.png)\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46226',
#   'id': 1159602954,
#   'node_id': 'PR_kwDOAA0YD84z8_b_',
#   'number': 46226,
#   'title': 'ENH: Let callables in .loc and .iloc take an optional axis parameter',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-03-04T12:37:52Z',
#   'updated_at': '2022-03-04T22:59:40Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46226',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46226',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46226.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46226.patch',
#    'merged_at': None},
#   'body': "Currently, when supplying callables to ``.loc``and ``.iloc`` we can't know which axis the callable is supplied for. This makes is  difficult to make more general filtering callables, e.g. if we want the callable to filter over transposed axes.\r\n\r\nThis PR allows the callables supplied to ``.loc`` and ``.iloc`` to take either one or two arguments, instead of only one argument, as it could previously.\r\n\r\nThis PR is fully backwards compatible.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46225',
#   'id': 1159567404,
#   'node_id': 'I_kwDOAA0YD85FHZgs',
#   'number': 46225,
#   'title': 'BUG: outer join out of order when joining multiple DataFrames',
#   'user': {'login': 'hitvoice',
#    'id': 13765633,
#    'node_id': 'MDQ6VXNlcjEzNzY1NjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13765633?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hitvoice',
#    'html_url': 'https://github.com/hitvoice',
#    'followers_url': 'https://api.github.com/users/hitvoice/followers',
#    'following_url': 'https://api.github.com/users/hitvoice/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hitvoice/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hitvoice/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hitvoice/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hitvoice/orgs',
#    'repos_url': 'https://api.github.com/users/hitvoice/repos',
#    'events_url': 'https://api.github.com/users/hitvoice/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hitvoice/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T11:56:56Z',
#   'updated_at': '2022-03-04T11:56:56Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\na = pd.DataFrame(np.ones((4, 2)), index=[3,2,1,0])\r\nb = pd.DataFrame(2*np.ones((2, 1)), columns=[2], index=[3,1])\r\nc = pd.DataFrame(3*np.ones((2, 1)), columns=[3], index=[3,1])\r\na.join(b, how='outer') # correct, the index is [0,1,2,3]\r\nb.join(a, how='outer') # correct, the index is [0,1,2,3]\r\na.join([b, c], how='outer') # incorrect, the index is [3,2,1,0]\r\nb.join([a, c], how='outer') # incorrect, the index is [3,1,2,0]\n```\n\n\n### Issue Description\n\nThe [document of join](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html) says:\r\n> outer: form union of calling frame’s index (or column if on is specified) with other’s index, **and sort it. lexicographically.**\r\n\r\nBut the behavior is not consistent. when joining more than 2 dataframes, the result remains unsorted, which is a bug.\r\n\n\n### Expected Behavior\n\nThe result should be sorted when outer joining multiple dataframes. This test should be passed for the example above:\r\n```python\r\nassert a.join([b, c], how='outer').equals(a.join([b, c], how='outer', sort=True))\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\n1.5.0.dev0+471.g8e0baa2360\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46222',
#   'id': 1159216249,
#   'node_id': 'PR_kwDOAA0YD84z7u8G',
#   'number': 46222,
#   'title': 'TYP: pd.isna',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-03-04T04:01:01Z',
#   'updated_at': '2022-03-05T00:07:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46222',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46222',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46222.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46222.patch',
#    'merged_at': None},
#   'body': 'Inferred by mypy and pyright:\r\n```py\r\nimport numpy as np\r\nimport pandas as pd\r\n\r\nclass A:\r\n    ...\r\n\r\n# bool\r\nreveal_type(pd.isna(1))\r\n\r\n# npt.NDArray[np.bool_]\r\nreveal_type(pd.isna([]))\r\nreveal_type(pd.isna(np.zeros(3)))\r\nreveal_type(pd.isna(pd.DatetimeIndex([None])))\r\n\r\n# pd.DataFrame\r\nreveal_type(pd.isna(pd.DataFrame()))\r\n\r\n# pd.Series\r\nreveal_type(pd.isna(pd.Series()))\r\n\r\n# Union of all possible cases\r\nreveal_type(pd.isna(A())) # should be bool\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46221',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46221/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46221/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46221/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46221',
#   'id': 1159140752,
#   'node_id': 'I_kwDOAA0YD85FFxWQ',
#   'number': 46221,
#   'title': "BUG: read_sql with query doesn't get metadata from the database",
#   'user': {'login': 'mvashishtha',
#    'id': 10712109,
#    'node_id': 'MDQ6VXNlcjEwNzEyMTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10712109?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mvashishtha',
#    'html_url': 'https://github.com/mvashishtha',
#    'followers_url': 'https://api.github.com/users/mvashishtha/followers',
#    'following_url': 'https://api.github.com/users/mvashishtha/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mvashishtha/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mvashishtha/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mvashishtha/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mvashishtha/orgs',
#    'repos_url': 'https://api.github.com/users/mvashishtha/repos',
#    'events_url': 'https://api.github.com/users/mvashishtha/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mvashishtha/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T01:23:39Z',
#   'updated_at': '2022-03-04T01:23:39Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46176/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46176/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46173',
#   'id': 1153437571,
#   'node_id': 'I_kwDOAA0YD85EwA-D',
#   'number': 46173,
#   'title': 'Missing keys in a selector list are matched to None-labeled entries of MultiIndex',
#   'user': {'login': 'macsakow',
#    'id': 10297014,
#    'node_id': 'MDQ6VXNlcjEwMjk3MDE0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10297014?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/macsakow',
#    'html_url': 'https://github.com/macsakow',
#    'followers_url': 'https://api.github.com/users/macsakow/followers',
#    'following_url': 'https://api.github.com/users/macsakow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/macsakow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/macsakow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/macsakow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/macsakow/orgs',
#    'repos_url': 'https://api.github.com/users/macsakow/repos',
#    'events_url': 'https://api.github.com/users/macsakow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/macsakow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-02-27T23:07:07Z',
#   'updated_at': '2022-02-28T12:59:47Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\ndf = pd.DataFrame.from_dict({\r\n    ("foo",): [1, 2, 3],\r\n    ("bar",): [5, 6, 7],\r\n    (None,): [8, 9, 0], \r\n})\r\ndf[[ ("missingKey",) ]] # returns the NaN-labeled column [8, 9, 0] instead of raising a KeyError\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nGiven a DataFrame with MultiIndex containing NaN values in its keys, then keys with missing labels on the same level as NaN values will retrieve the NaN-labeled columns if keys are passed in a list.\r\n\r\nIf multiple missing labels are passed, each of them will retrieve the None column\r\n```python\r\npd.DataFrame.from_dict({(None,): [8, 9, 0]}).loc[:, [("foo",), ("bar",)]]  # returns a DF with two copies of the NaN-labeled [8, 9, 0] column \r\n``` \r\n\r\nThis behaviour occurs only when selection is done via a list of keys. \r\n```python\r\npd.DataFrame.from_dict({(None,): [8, 9, 0]}).loc[:, ("foo",)]  # single key - raises KeyError\r\npd.DataFrame.from_dict({(None,): [8, 9, 0]}).loc[:, [("foo",)]]  # key in a list - returns [8,9,0]\r\n```\r\n\r\nThe same issue occurs for multi-level MultiIndex, as long as missing labels in the selector occur only on the same level as NaN values.\r\n```python\r\npd.DataFrame.from_dict({(None,None): [8, 9, 0]}).loc[:, [("a","a")]]  # returns [8, 9, 0]\r\npd.DataFrame.from_dict({(None,None): [8, 9, 0]}).loc[:, [("a","b")]]  # returns [8, 9, 0]\r\npd.DataFrame.from_dict({(None,"b"): [8, 9, 0]}).loc[:, [("a","b")]]  # returns [8, 9, 0]\r\npd.DataFrame.from_dict({(None,"a"): [8, 9, 0]}).loc[:, [("a","b")]]  # KeyError, because 2nd level didn\'t match\r\n```\r\n\r\n`None` can also be replaced with any of `pd.NA`, `np.nan`, `pd.NaT` for the same effect. \r\n\r\nAn additional, more complex example, with multiple `None` in index.\r\n```python\r\ndf = pd.DataFrame.from_dict({\r\n    (None,None): [1, 2, 3],\r\n    (None,"a"): [5, 6, 7],\r\n    ("b",None): [8, 9, 0],\r\n})\r\n\r\ndf[[("foo", "bar")]] # returns [1,2,3]\r\ndf[[("foo", "a")]] # returns [5,6,7]\r\ndf[[("b", "foo")]] # returns [8,9,0]\r\ndf[[("b", "a")]] # raises KeyError\r\n```\r\nInterestingly enough, if `[("a", "b")]` is used to select from this DF, a KeyError *will* be raised, instead of matching it to (None, None).\r\n\r\n\r\n### Expected Behavior\r\n\r\nA KeyError should be raised, as it would be if the key with missing label was not wrapped in a list.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.13.0-27-generic\r\nVersion          : #29~20.04.1-Ubuntu SMP Fri Jan 14 00:32:30 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_GB.UTF-8\r\nLOCALE           : en_GB.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 20.0.2\r\nsetuptools       : 44.0.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : 1.0.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 8.0.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib   ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46171',
#   'id': 1153397978,
#   'node_id': 'PR_kwDOAA0YD84zoOh4',
#   'number': 46171,
#   'title': 'TYP: remove NaTType as possible result of Timestamp and Timedelta constructor',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49597148,
#     'node_id': 'MDU6TGFiZWw0OTU5NzE0OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timedelta',
#     'name': 'Timedelta',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timedelta data type'},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'},
#    {'id': 3877216987,
#     'node_id': 'LA_kwDOAA0YD87nGaLb',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timestamp',
#     'name': 'Timestamp',
#     'color': '5DE3E8',
#     'default': False,
#     'description': 'Cod related to pd.Timestamp'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 12,
#   'created_at': '2022-02-27T21:00:33Z',
#   'updated_at': '2022-03-03T18:36:12Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46171',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46171',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46171.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46171.patch',
#    'merged_at': None},
#   'body': 'While working on the Microsoft type stubs, I discovered this.  With the current code, if you run `pyright` on the following with default settings for basic type checking (not using what we have in `pyproject.toml`):\r\n```python\r\nimport pandas as pd\r\nprint("version ", pd.__version__)\r\nts:pd.Timestamp =  pd.Timestamp("2022-02-27")\r\nprint(ts)\r\n```\r\nyou get this:\r\n```\r\nc:\\Code\\pandas_dev\\pandas\\tstest.py\r\n  c:\\Code\\pandas_dev\\pandas\\tstest.py:3:20 - error: Expression of type "Timestamp | NaTType" cannot be assigned to declared type "Timestamp"\r\n  \xa0\xa0Type "Timestamp | NaTType" cannot be assigned to type "Timestamp"\r\n  \xa0\xa0\xa0\xa0"NaTType" is incompatible with "Timestamp" (reportGeneralTypeIssues)\r\n```\r\n`mypy` doesn\'t pick this up.  The real issue here is that you generally expect a `Timestamp` constructor to return a `Timestamp`, so by returning the `Union`, we are then forcing end users to `cast` the result of the constructor, which is pretty inconvenient.\r\n\r\nSo even though the constructor _could_ return a `NaTType`, we shouldn\'t force users to code for that due to static type checking.\r\n\r\nThis PR just takes out the `NaTType` as a return type for the constructors.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46167',
#   'id': 1153244393,
#   'node_id': 'PR_kwDOAA0YD84znvRb',
#   'number': 46167,
#   'title': 'Bug fix - rename dataframe reset index',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-02-27T13:06:18Z',
#   'updated_at': '2022-03-03T16:27:36Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46167',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46167',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46167.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46167.patch',
#    'merged_at': None},
#   'body': '- [x] closes #6878\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/timeline',
#   'performed_via_github_app': None}]

# %%
len(data1) # Find the number of dict in list result
# Out:
# 30

# %%
data1[0]['user']['id']
# Out:
# 8078968

# %%
# Let's say we need this user id for all the 30 dicts
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 8078968
# 8078968
# 56136443
# 20362314
# 30196
# 54762742
# 1020496
# 26364415
# 13765633
# 6618166
# 10712109
# 8078968
# 25179211
# 18547401
# 45562402
# 10820686
# 414652
# 8078968
# 10820686
# 100778886
# 36619387
# 46936498
# 51996504
# 25440862
# 5902745
# 4156237
# 100502242
# 10297014
# 15113894
# 36619387

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46236',
#   'id': 1160198674,
#   'node_id': 'PR_kwDOAA0YD84z-8mt',
#   'number': 46236,
#   'title': 'troubleshoot 32bit build',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-05T02:51:25Z',
#   'updated_at': '2022-03-05T02:51:25Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46236',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46236',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46236.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46236.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46236/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46234',
#   'id': 1160089928,
#   'node_id': 'PR_kwDOAA0YD84z-mBc',
#   'number': 46234,
#   'title': 'REF: use standard pattern in _tz_convert_from_utc',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 60458168,
#     'node_id': 'MDU6TGFiZWw2MDQ1ODE2OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timezones',
#     'name': 'Timezones',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timezone data dtype'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 51,
#    'closed_issues': 445,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-05T01:17:43Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-03-04T22:07:03Z',
#   'updated_at': '2022-03-05T01:06:08Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46234',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46234',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46234.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46234.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAvoid unnecessary copy in non-UTC cases.\r\nConfirmed that the "TODO: How is this reached" case is not reachable, so removed it.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46234/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46232',
#   'id': 1160064471,
#   'node_id': 'PR_kwDOAA0YD84z-gzl',
#   'number': 46232,
#   'title': 'Adding overwrite or ignore behavior for row conflicts.',
#   'user': {'login': 'LSturtew',
#    'id': 56136443,
#    'node_id': 'MDQ6VXNlcjU2MTM2NDQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56136443?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LSturtew',
#    'html_url': 'https://github.com/LSturtew',
#    'followers_url': 'https://api.github.com/users/LSturtew/followers',
#    'following_url': 'https://api.github.com/users/LSturtew/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LSturtew/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LSturtew/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LSturtew/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LSturtew/orgs',
#    'repos_url': 'https://api.github.com/users/LSturtew/repos',
#    'events_url': 'https://api.github.com/users/LSturtew/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LSturtew/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T21:26:16Z',
#   'updated_at': '2022-03-04T21:26:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46232',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46232',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46232.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46232.patch',
#    'merged_at': None},
#   'body': "@cvonsteg started the effort to implement this. Since they are unable to continue and this is a highly desired feature, I made an attempt to clean up the code and fix merge conflicts. I would like to share the credit for this PR (I do not know how this works).\r\n\r\nA new parameter is added to `to_sql`: `on_row_conflct`\r\n\r\n    on_row_conflict : {'fail', 'overwrite', 'append'},\r\n        default: 'fail'\r\n        Determine insertion behavior in case of a primary key clash.\r\n        - 'fail': Do nothing to handle primary key clashes, will raise an Error.\r\n        - 'overwrite': Update existing rows in database with primary key clashes,\r\n          and append the remaining rows with non-conflicting primary keys\r\n        - 'append': Ignore incoming rows with primary key clashes, and\r\n          insert only the incoming rows with non-conflicting primary keys\r\n\r\n\r\n\r\n\r\n- [x] closes #14553, continuation of #29636\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46232/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46231',
#   'id': 1159934807,
#   'node_id': 'PR_kwDOAA0YD84z-FU6',
#   'number': 46231,
#   'title': 'DOC: Added plt.show() at the end of each necessary block',
#   'user': {'login': 'ehallam',
#    'id': 20362314,
#    'node_id': 'MDQ6VXNlcjIwMzYyMzE0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20362314?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ehallam',
#    'html_url': 'https://github.com/ehallam',
#    'followers_url': 'https://api.github.com/users/ehallam/followers',
#    'following_url': 'https://api.github.com/users/ehallam/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ehallam/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ehallam/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ehallam/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ehallam/orgs',
#    'repos_url': 'https://api.github.com/users/ehallam/repos',
#    'events_url': 'https://api.github.com/users/ehallam/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ehallam/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T18:36:18Z',
#   'updated_at': '2022-03-04T18:36:18Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46231',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46231',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46231.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46231.patch',
#    'merged_at': None},
#   'body': 'Moved title to the top of page and reworded title\r\n\r\n- [ ] closes #45772 \r\n- [x] ~[Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature~\r\n- [x] ~All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).~\r\n- [x] ~Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.~\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46231/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46230',
#   'id': 1159874789,
#   'node_id': 'I_kwDOAA0YD85FIkjl',
#   'number': 46230,
#   'title': 'BUG: pd.DataFrame.interpolate fails with ValueError: x and y arrays must have at least 2 entries',
#   'user': {'login': 'ianliu',
#    'id': 30196,
#    'node_id': 'MDQ6VXNlcjMwMTk2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30196?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ianliu',
#    'html_url': 'https://github.com/ianliu',
#    'followers_url': 'https://api.github.com/users/ianliu/followers',
#    'following_url': 'https://api.github.com/users/ianliu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ianliu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ianliu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ianliu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ianliu/orgs',
#    'repos_url': 'https://api.github.com/users/ianliu/repos',
#    'events_url': 'https://api.github.com/users/ianliu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ianliu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T17:19:14Z',
#   'updated_at': '2022-03-04T17:19:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport numpy as np\r\n\r\npd.DataFrame(dict(a=[np.nan, 1])).interpolate(method="nearest")\n```\n\n\n### Issue Description\n\nThe example fails with a Scipy exception which says:\r\n\r\n    ValueError: x and y arrays must have at least 2 entries\r\n\r\nThe following examples all work as intended:\r\n\r\n```python\r\n>>> pd.DataFrame(dict(a=[np.nan])).interpolate(method="nearest")\r\n#     a\r\n# 0 NaN\r\n\r\n>>> pd.DataFrame(dict(a=[np.nan, np.nan])).interpolate(method="nearest")\r\n#     a\r\n# 0 NaN\r\n# 1 NaN\r\n\r\n>>> pd.DataFrame(dict(a=[np.nan, 1, 1 np.nan])).interpolate(method="nearest")\r\n#     a\r\n# 0 NaN\r\n# 1 1.0\r\n# 2 1.0\r\n# 3 NaN\r\n```\n\n### Expected Behavior\n\n```python\r\n>>> pd.DataFrame(dict(a=[np.nan, 1])).interpolate(method="nearest")\r\n#     a\r\n# 0 NaN\r\n# 1 1.0\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.10.2.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.16.12-arch1-1\r\nVersion          : #1 SMP PREEMPT Wed, 02 Mar 2022 12:22:51 +0000\r\nmachine          : x86_64\r\nprocessor        : \r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 21.0\r\nsetuptools       : 59.3.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : 4.4.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.7.1\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.0.3\r\nIPython          : 8.1.0\r\npandas_datareader: 0.10.0\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : 2021.10.1\r\ngcsfs            : None\r\nmatplotlib       : 3.5.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 6.0.1\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.0\r\nsqlalchemy       : 1.4.30\r\ntables           : None\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46230/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46229',
#   'id': 1159791857,
#   'node_id': 'I_kwDOAA0YD85FIQTx',
#   'number': 46229,
#   'title': 'BUG: ',
#   'user': {'login': 'raffaem',
#    'id': 54762742,
#    'node_id': 'MDQ6VXNlcjU0NzYyNzQy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54762742?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raffaem',
#    'html_url': 'https://github.com/raffaem',
#    'followers_url': 'https://api.github.com/users/raffaem/followers',
#    'following_url': 'https://api.github.com/users/raffaem/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/raffaem/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/raffaem/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/raffaem/subscriptions',
#    'organizations_url': 'https://api.github.com/users/raffaem/orgs',
#    'repos_url': 'https://api.github.com/users/raffaem/repos',
#    'events_url': 'https://api.github.com/users/raffaem/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/raffaem/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-04T15:54:29Z',
#   'updated_at': '2022-03-05T00:44:21Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nI\'m calling this on a .csv file:\r\n\r\n```python\r\n\r\n#!/usr/bin/env python3\r\n\r\nimport pandas as pd\r\nimport sys\r\n\r\ninfp = sys.argv[1]\r\noutfp = infp.replace(".csv",".dta")\r\ndf = pd.read_csv(infp, header=0, low_memory=False) \r\ndf.to_stata(outfp, version=118, write_index=False)\r\n```\r\n\r\n### Issue Description\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "/run/media/raffaele/55ab61c4-83cf-4d9f-a5cd-7fcfdc14b4fb/data/progetti_miei/various_tools/csv2dta", line 9, in <module>\r\n    df.to_stata(outfp, version=118, write_index=False)\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/util/_decorators.py", line 207, in wrapper\r\n    return func(*args, **kwargs)\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/core/frame.py", line 2652, in to_stata\r\n    writer.write_file()\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 2659, in write_file\r\n    raise exc\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 2639, in write_file\r\n    records = self._prepare_data()\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 2827, in _prepare_data\r\n    data = self._convert_strls(data)\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 3454, in _convert_strls\r\n    self._strl_blob = ssw.generate_blob(tab)\r\n  File "/home/raffaele/.local/lib/python3.10/site-packages/pandas/io/stata.py", line 3081, in generate_blob\r\n    utf8_string = bytes(strl, "utf-8")\r\nTypeError: encoding without a string argument\r\n```\r\n\r\n### Expected Behavior\r\n\r\nShould not raise an exception\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n>>> pd.show_versions()\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.10.2.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.16.10-200.fc35.x86_64\r\nVersion          : #1 SMP PREEMPT Wed Feb 16 13:28:00 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.1\r\npip              : 21.2.3\r\nsetuptools       : 57.4.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.7.1\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.1\r\nIPython          : 7.29.0\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.5.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.9\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.0\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46229/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46227',
#   'id': 1159657724,
#   'node_id': 'PR_kwDOAA0YD84z9LNE',
#   'number': 46227,
#   'title': 'DOC: migrate from sphinx-panels to sphinx-design',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T13:39:17Z',
#   'updated_at': '2022-03-04T13:39:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46227',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46227',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46227.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46227.patch',
#    'merged_at': None},
#   'body': 'Eventually it is the goal that the sphinx-design package replaces the sphinx-panels package (see https://github.com/executablebooks/sphinx-panels/issues/67 and https://sphinx-design.readthedocs.io/en/furo-theme/get_started.html#migrating-from-sphinx-panels, sphinx-design has the same (and more) features, but with a refactored and more flexible code base). \r\n\r\nSo this PR moves our usage of sphinx-panels to sphinx-design (at least already for the front page, still need to do the same for the getting started pages)\r\n\r\nIt gives almost identical result as we have now (screenshot is with this PR, compare with eg https://pandas.pydata.org/pandas-docs/version/1.3/):\r\n\r\n![image](https://user-images.githubusercontent.com/1020496/156773002-735b352e-26ad-408e-b792-9f3325f2e277.png)\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46227/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46226',
#   'id': 1159602954,
#   'node_id': 'PR_kwDOAA0YD84z8_b_',
#   'number': 46226,
#   'title': 'ENH: Let callables in .loc and .iloc take an optional axis parameter',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-03-04T12:37:52Z',
#   'updated_at': '2022-03-04T22:59:40Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46226',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46226',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46226.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46226.patch',
#    'merged_at': None},
#   'body': "Currently, when supplying callables to ``.loc``and ``.iloc`` we can't know which axis the callable is supplied for. This makes is  difficult to make more general filtering callables, e.g. if we want the callable to filter over transposed axes.\r\n\r\nThis PR allows the callables supplied to ``.loc`` and ``.iloc`` to take either one or two arguments, instead of only one argument, as it could previously.\r\n\r\nThis PR is fully backwards compatible.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46226/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46225',
#   'id': 1159567404,
#   'node_id': 'I_kwDOAA0YD85FHZgs',
#   'number': 46225,
#   'title': 'BUG: outer join out of order when joining multiple DataFrames',
#   'user': {'login': 'hitvoice',
#    'id': 13765633,
#    'node_id': 'MDQ6VXNlcjEzNzY1NjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13765633?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hitvoice',
#    'html_url': 'https://github.com/hitvoice',
#    'followers_url': 'https://api.github.com/users/hitvoice/followers',
#    'following_url': 'https://api.github.com/users/hitvoice/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hitvoice/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hitvoice/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hitvoice/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hitvoice/orgs',
#    'repos_url': 'https://api.github.com/users/hitvoice/repos',
#    'events_url': 'https://api.github.com/users/hitvoice/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hitvoice/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T11:56:56Z',
#   'updated_at': '2022-03-04T11:56:56Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\na = pd.DataFrame(np.ones((4, 2)), index=[3,2,1,0])\r\nb = pd.DataFrame(2*np.ones((2, 1)), columns=[2], index=[3,1])\r\nc = pd.DataFrame(3*np.ones((2, 1)), columns=[3], index=[3,1])\r\na.join(b, how='outer') # correct, the index is [0,1,2,3]\r\nb.join(a, how='outer') # correct, the index is [0,1,2,3]\r\na.join([b, c], how='outer') # incorrect, the index is [3,2,1,0]\r\nb.join([a, c], how='outer') # incorrect, the index is [3,1,2,0]\n```\n\n\n### Issue Description\n\nThe [document of join](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html) says:\r\n> outer: form union of calling frame’s index (or column if on is specified) with other’s index, **and sort it. lexicographically.**\r\n\r\nBut the behavior is not consistent. when joining more than 2 dataframes, the result remains unsorted, which is a bug.\r\n\n\n### Expected Behavior\n\nThe result should be sorted when outer joining multiple dataframes. This test should be passed for the example above:\r\n```python\r\nassert a.join([b, c], how='outer').equals(a.join([b, c], how='outer', sort=True))\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\n1.5.0.dev0+471.g8e0baa2360\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46225/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46222',
#   'id': 1159216249,
#   'node_id': 'PR_kwDOAA0YD84z7u8G',
#   'number': 46222,
#   'title': 'TYP: pd.isna',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-03-04T04:01:01Z',
#   'updated_at': '2022-03-05T00:07:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46222',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46222',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46222.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46222.patch',
#    'merged_at': None},
#   'body': 'Inferred by mypy and pyright:\r\n```py\r\nimport numpy as np\r\nimport pandas as pd\r\n\r\nclass A:\r\n    ...\r\n\r\n# bool\r\nreveal_type(pd.isna(1))\r\n\r\n# npt.NDArray[np.bool_]\r\nreveal_type(pd.isna([]))\r\nreveal_type(pd.isna(np.zeros(3)))\r\nreveal_type(pd.isna(pd.DatetimeIndex([None])))\r\n\r\n# pd.DataFrame\r\nreveal_type(pd.isna(pd.DataFrame()))\r\n\r\n# pd.Series\r\nreveal_type(pd.isna(pd.Series()))\r\n\r\n# Union of all possible cases\r\nreveal_type(pd.isna(A())) # should be bool\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46222/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46221',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46221/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46221/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46221/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46221',
#   'id': 1159140752,
#   'node_id': 'I_kwDOAA0YD85FFxWQ',
#   'number': 46221,
#   'title': "BUG: read_sql with query doesn't get metadata from the database",
#   'user': {'login': 'mvashishtha',
#    'id': 10712109,
#    'node_id': 'MDQ6VXNlcjEwNzEyMTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10712109?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mvashishtha',
#    'html_url': 'https://github.com/mvashishtha',
#    'followers_url': 'https://api.github.com/users/mvashishtha/followers',
#    'following_url': 'https://api.github.com/users/mvashishtha/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mvashishtha/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mvashishtha/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mvashishtha/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mvashishtha/orgs',
#    'repos_url': 'https://api.github.com/users/mvashishtha/repos',
#    'events_url': 'https://api.github.com/users/mvashishtha/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mvashishtha/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-04T01:23:39Z',
#   'updated_at': '2022-03-04T01:23:39Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46176/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46176/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46173',
#   'id': 1153437571,
#   'node_id': 'I_kwDOAA0YD85EwA-D',
#   'number': 46173,
#   'title': 'Missing keys in a selector list are matched to None-labeled entries of MultiIndex',
#   'user': {'login': 'macsakow',
#    'id': 10297014,
#    'node_id': 'MDQ6VXNlcjEwMjk3MDE0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10297014?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/macsakow',
#    'html_url': 'https://github.com/macsakow',
#    'followers_url': 'https://api.github.com/users/macsakow/followers',
#    'following_url': 'https://api.github.com/users/macsakow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/macsakow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/macsakow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/macsakow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/macsakow/orgs',
#    'repos_url': 'https://api.github.com/users/macsakow/repos',
#    'events_url': 'https://api.github.com/users/macsakow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/macsakow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-02-27T23:07:07Z',
#   'updated_at': '2022-02-28T12:59:47Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\ndf = pd.DataFrame.from_dict({\r\n    ("foo",): [1, 2, 3],\r\n    ("bar",): [5, 6, 7],\r\n    (None,): [8, 9, 0], \r\n})\r\ndf[[ ("missingKey",) ]] # returns the NaN-labeled column [8, 9, 0] instead of raising a KeyError\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nGiven a DataFrame with MultiIndex containing NaN values in its keys, then keys with missing labels on the same level as NaN values will retrieve the NaN-labeled columns if keys are passed in a list.\r\n\r\nIf multiple missing labels are passed, each of them will retrieve the None column\r\n```python\r\npd.DataFrame.from_dict({(None,): [8, 9, 0]}).loc[:, [("foo",), ("bar",)]]  # returns a DF with two copies of the NaN-labeled [8, 9, 0] column \r\n``` \r\n\r\nThis behaviour occurs only when selection is done via a list of keys. \r\n```python\r\npd.DataFrame.from_dict({(None,): [8, 9, 0]}).loc[:, ("foo",)]  # single key - raises KeyError\r\npd.DataFrame.from_dict({(None,): [8, 9, 0]}).loc[:, [("foo",)]]  # key in a list - returns [8,9,0]\r\n```\r\n\r\nThe same issue occurs for multi-level MultiIndex, as long as missing labels in the selector occur only on the same level as NaN values.\r\n```python\r\npd.DataFrame.from_dict({(None,None): [8, 9, 0]}).loc[:, [("a","a")]]  # returns [8, 9, 0]\r\npd.DataFrame.from_dict({(None,None): [8, 9, 0]}).loc[:, [("a","b")]]  # returns [8, 9, 0]\r\npd.DataFrame.from_dict({(None,"b"): [8, 9, 0]}).loc[:, [("a","b")]]  # returns [8, 9, 0]\r\npd.DataFrame.from_dict({(None,"a"): [8, 9, 0]}).loc[:, [("a","b")]]  # KeyError, because 2nd level didn\'t match\r\n```\r\n\r\n`None` can also be replaced with any of `pd.NA`, `np.nan`, `pd.NaT` for the same effect. \r\n\r\nAn additional, more complex example, with multiple `None` in index.\r\n```python\r\ndf = pd.DataFrame.from_dict({\r\n    (None,None): [1, 2, 3],\r\n    (None,"a"): [5, 6, 7],\r\n    ("b",None): [8, 9, 0],\r\n})\r\n\r\ndf[[("foo", "bar")]] # returns [1,2,3]\r\ndf[[("foo", "a")]] # returns [5,6,7]\r\ndf[[("b", "foo")]] # returns [8,9,0]\r\ndf[[("b", "a")]] # raises KeyError\r\n```\r\nInterestingly enough, if `[("a", "b")]` is used to select from this DF, a KeyError *will* be raised, instead of matching it to (None, None).\r\n\r\n\r\n### Expected Behavior\r\n\r\nA KeyError should be raised, as it would be if the key with missing label was not wrapped in a list.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.13.0-27-generic\r\nVersion          : #29~20.04.1-Ubuntu SMP Fri Jan 14 00:32:30 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_GB.UTF-8\r\nLOCALE           : en_GB.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 20.0.2\r\nsetuptools       : 44.0.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : 1.0.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 8.0.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib   ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46173/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46171',
#   'id': 1153397978,
#   'node_id': 'PR_kwDOAA0YD84zoOh4',
#   'number': 46171,
#   'title': 'TYP: remove NaTType as possible result of Timestamp and Timedelta constructor',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49597148,
#     'node_id': 'MDU6TGFiZWw0OTU5NzE0OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timedelta',
#     'name': 'Timedelta',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timedelta data type'},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'},
#    {'id': 3877216987,
#     'node_id': 'LA_kwDOAA0YD87nGaLb',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timestamp',
#     'name': 'Timestamp',
#     'color': '5DE3E8',
#     'default': False,
#     'description': 'Cod related to pd.Timestamp'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 12,
#   'created_at': '2022-02-27T21:00:33Z',
#   'updated_at': '2022-03-03T18:36:12Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46171',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46171',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46171.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46171.patch',
#    'merged_at': None},
#   'body': 'While working on the Microsoft type stubs, I discovered this.  With the current code, if you run `pyright` on the following with default settings for basic type checking (not using what we have in `pyproject.toml`):\r\n```python\r\nimport pandas as pd\r\nprint("version ", pd.__version__)\r\nts:pd.Timestamp =  pd.Timestamp("2022-02-27")\r\nprint(ts)\r\n```\r\nyou get this:\r\n```\r\nc:\\Code\\pandas_dev\\pandas\\tstest.py\r\n  c:\\Code\\pandas_dev\\pandas\\tstest.py:3:20 - error: Expression of type "Timestamp | NaTType" cannot be assigned to declared type "Timestamp"\r\n  \xa0\xa0Type "Timestamp | NaTType" cannot be assigned to type "Timestamp"\r\n  \xa0\xa0\xa0\xa0"NaTType" is incompatible with "Timestamp" (reportGeneralTypeIssues)\r\n```\r\n`mypy` doesn\'t pick this up.  The real issue here is that you generally expect a `Timestamp` constructor to return a `Timestamp`, so by returning the `Union`, we are then forcing end users to `cast` the result of the constructor, which is pretty inconvenient.\r\n\r\nSo even though the constructor _could_ return a `NaTType`, we shouldn\'t force users to code for that due to static type checking.\r\n\r\nThis PR just takes out the `NaTType` as a return type for the constructors.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46171/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46167',
#   'id': 1153244393,
#   'node_id': 'PR_kwDOAA0YD84znvRb',
#   'number': 46167,
#   'title': 'Bug fix - rename dataframe reset index',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-02-27T13:06:18Z',
#   'updated_at': '2022-03-03T16:27:36Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46167',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46167',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46167.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46167.patch',
#    'merged_at': None},
#   'body': '- [x] closes #6878\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46167/timeline',
#   'performed_via_github_app': None}]

# %%
# filter selected fields for all 30 dicts in above list
pd.DataFrame(data1, columns=['id','url','repository_url','labels_url']).head(2)
# Out:
#            id                                                url  \
# 0  1160198674  https://api.github.com/repos/pandas-dev/pandas...
# 1  1160089928  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...

# %%
# Lets get user also
pd.DataFrame(data1, columns=['id','url','repository_url','labels_url','user']).head(2)
# Out:
#            id                                                url  \
# 0  1160198674  https://api.github.com/repos/pandas-dev/pandas...
# 1  1160089928  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 user
# 0  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1  {'login': 'jbrockmendel', 'id': 8078968, 'node...

# %%
df = pd.DataFrame(data1)
df.head(2)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           html_url          id  \
# 0  https://github.com/pandas-dev/pandas/pull/46236  1160198674
# 1  https://github.com/pandas-dev/pandas/pull/46234  1160089928
#
#                node_id  number  \
# 0  PR_kwDOAA0YD84z-8mt   46236
# 1  PR_kwDOAA0YD84z-mBc   46234
#
#                                                title  ...  \
# 0                           troubleshoot 32bit build  ...
# 1  REF: use standard pattern in _tz_convert_from_utc  ...
#
#              updated_at closed_at author_association  active_lock_reason  \
# 0  2022-03-05T02:51:25Z      None             MEMBER                None
# 1  2022-03-05T01:06:08Z      None             MEMBER                None
#
#    draft                                       pull_request  \
# 0  False  {'url': 'https://api.github.com/repos/pandas-d...
# 1  False  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                 body  \
# 0  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 1  - [ ] closes #xxxx (Replace xxxx with the Gith...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app
# 0  https://api.github.com/repos/pandas-dev/pandas...                     None
# 1  https://api.github.com/repos/pandas-dev/pandas...                     None
#
# [2 rows x 29 columns]

# %%
df4 = pd.json_normalize(df['user']).head(2) # Now add these user columns to existing dataframe

# %%
df5 =
