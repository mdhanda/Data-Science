# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 24B2-47A3
#
#  Directory of C:\Users\Manu
#
# 26/02/2022  06:47 PM    <DIR>          .
# 26/02/2022  06:47 PM    <DIR>          ..
# 18/02/2018  05:05 PM    <DIR>          .anaconda
# 10/08/2020  02:30 AM    <DIR>          .astropy
# 05/02/2022  09:54 PM             9,891 .bash_history
# 02/06/2019  11:39 PM    <DIR>          .cache
# 23/11/2019  02:49 PM    <DIR>          .cargo
# 04/02/2022  07:36 AM    <DIR>          .conda
# 09/08/2020  02:51 PM                43 .condarc
# 04/02/2022  07:36 AM    <DIR>          .continuum
# 19/03/2019  07:48 PM    <DIR>          .cura
# 09/05/2016  02:36 PM    <DIR>          .electron
# 12/02/2022  07:17 PM               406 .gitconfig
# 26/02/2022  05:19 PM    <DIR>          .ipynb_checkpoints
# 04/02/2022  08:03 AM    <DIR>          .ipython
# 20/02/2022  10:02 PM    <DIR>          .jupyter
# 19/12/2016  05:46 PM    <DIR>          .Leapdroid
# 05/02/2022  09:01 PM                20 .lesshst
# ...

# %%
pd.read_csv('sample_test.csv')
# Out:
#      name           emailid    address  pin code surname
# 0    Manu    manu@email.com     Sydney      2153  Dhanda
# 1  Maanav  maanav@email.com  Bangalore      2200   Singh

# %%
pd.read_csv('d://DS/datasets/sample-csv/taxonomy.csv')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# By default pandas think that very first row is column names

# What if we have data where first row is not column names??

# %%
pd.read_csv('d://DS/datasets/sample-csv/taxonomy.csv', header=None)
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
# Providde own column names
pd.read_csv('d://DS/datasets/sample-csv/taxonomy.csv', names=['a', 'b', 'c','d'])
# Out:
#                                         a          b                     c
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
df = pd.read_csv('d://DS/datasets/sample-csv/taxonomy.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# define your own separator
pd.read_csv('d://DS/datasets/sample-csv/taxonomy.csv', sep='@')
# Out:
#                 taxonomy_id,name,parent_id,parent_name
# 0                                      101,Emergency,,
# 1               101-01,Disaster Response,101,Emergency
# 2                  101-02,Emergency Cash,101,Emergency
# 3    101-02-01,Help Pay for Food,101-02,Emergency Cash
# 4    101-02-02,Help Pay for Healthcare,101-02,Emerg...
# ..                                                 ...
# 285  111-01-07,Workplace Rights,111-01,Advocacy & L...
# 286                         111-02,Mediation,111,Legal
# 287                            111-03,Notary,111,Legal
# 288                    111-04,Representation,111,Legal
# 289      111-05,Translation & Interpretation,111,Legal
#
# [290 rows x 1 columns]

# %%
pd.read_csv('data/taxonomy.csv')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
pd.read_csv('data/taxonomy.csv', skiprows=[1,5])
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0        101-01             Disaster Response       101             Emergency
# 1        101-02                Emergency Cash       101             Emergency
# 2     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 3     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# 4     101-02-04              Help Pay for Gas    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 283   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 284      111-02                     Mediation       111                 Legal
# 285      111-03                        Notary       111                 Legal
# 286      111-04                Representation       111                 Legal
# 287      111-05  Translation & Interpretation       111                 Legal
#
# [288 rows x 4 columns]

# %%
df = pd.read_csv('data/services.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Lets find column data types
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.head() # default - shows first 5 records, df.head(2) - shows first 2 records
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
# See what all column names are available
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
# See only selected columns
df['name']
# Out:
# 0          Fair Oaks Adult Activity Center
# 1         Second Career Employment Program
# 2                   Senior Peer Counseling
# 3                 Family Visitation Center
# 4        Economic Self-Sufficiency Program
# 5     Little House Recreational Activities
# 6         Rosener House Adult Day Services
# 7           Meals on Wheels - South County
# 8                         Fair Oaks Branch
# 9                             Main Library
# 10                         Schaberg Branch
# 11                            Project Read
# 12                   Redwood Shores Branch
# 13                      Redwood City Corps
# 14             Adult Rehabilitation Center
# 15                         Sunnyvale Corps
# 16       South San Francisco Citadel Corps
# 17                           Project Smile
# 18           San Mateo Free Medical Clinic
# 19               Service with blank fields
# 20         Service for Admin Test Location
# 21                         Passport Photos
# ...

# %%
a = df['name']
type(a)
# Out:
# pandas.core.series.Series

# %%
a = df[['name']] # As we passed a list
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
# DataFrame - Multi-dimentional
# Series - Single dimentional
# So whenever you call a single column OR row, it will be returned as a series

# %%
# df['name', 'location_id'] # Error

df[['name', 'location_id']] # Need to pass in []
# Out:
#                                     name  location_id
# 0        Fair Oaks Adult Activity Center            1
# 1       Second Career Employment Program            2
# 2                 Senior Peer Counseling            3
# 3               Family Visitation Center            4
# 4      Economic Self-Sufficiency Program            5
# 5   Little House Recreational Activities            6
# 6       Rosener House Adult Day Services            7
# 7         Meals on Wheels - South County            8
# 8                       Fair Oaks Branch            9
# 9                           Main Library           10
# 10                       Schaberg Branch           11
# 11                          Project Read           12
# 12                 Redwood Shores Branch           13
# 13                    Redwood City Corps           14
# 14           Adult Rehabilitation Center           15
# 15                       Sunnyvale Corps           16
# ...

# %%
# Reading Excel Sheets
pd.read_excel('data/airline.xls')
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
df = pd.ExcelFile('data/airline.xls') # Use ExcelFile for getting the sheet names
df.sheet_names
# Out:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
for i in df.sheet_names:
    pd.read_excel('data/airline.xls', sheet_name=i)

# %%
# pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv') # Will give error

pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv') # Use 'raw' data url on git page
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
